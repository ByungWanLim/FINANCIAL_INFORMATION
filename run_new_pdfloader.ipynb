# %%
# Model
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline, BitsAndBytesConfig
from langchain_huggingface import HuggingFacePipeline
import torch
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain.prompts import PromptTemplate
# Vector stores
import fitz  # PyMuPDF
import pdfplumber
from langchain_community.vectorstores import FAISS
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.document_loaders import PyMuPDFLoader, PDFPlumberLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.retrievers import BM25Retriever, KNNRetriever
from langchain.retrievers import EnsembleRetriever
from langchain_community.vectorstores import FAISS
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.document_loaders import PyMuPDFLoader, PDFPlumberLoader
from langchain_community.retrievers import BM25Retriever, KNNRetriever
from langchain.retrievers import EnsembleRetriever
from langchain_teddynote.retrievers import KiwiBM25Retriever
from langchain.docstore.document import Document
from concurrent.futures import ThreadPoolExecutor
import pandas as pd
import unicodedata
import time
import re
# etc
import os
import pandas as pd
from tqdm import tqdm
import unicodedata
import logging

# %%
# sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# intfloat/multilingual-e5-small
# jhgan/ko-sroberta-multitask

# %%
def get_embedding():
    device = 'cuda' if torch.cuda.is_available() and 'mps' in torch.cuda.get_device_capability() else 'cpu'  # GPU 사용 가능 여부 및 MPS 지원 여부 확인
    embeddings = HuggingFaceEmbeddings(
        model_name='jhgan/ko-sroberta-multitask',
        model_kwargs={'device': device},
        encode_kwargs={'normalize_embeddings': True})
    return embeddings

def normalize_string(s):
    try:
        normalized = unicodedata.normalize('NFC', s)
        return normalized.encode('utf-8', errors='replace').decode('utf-8')
    except Exception:
        return s

def clean_text(text):
    text = text.replace("�", "").replace("", "")  # 잘못된 인코딩 문자 제거
    text = ' '.join(text.split())  # 여러 공백을 하나로 줄임
    return text

def extract_text_and_tables(pdf_path):
    text_content = ""
    try:
        # fitz를 사용한 텍스트 추출
        doc = fitz.open(pdf_path)
        for page in doc:
            text = page.get_text("text")
            if text:
                text = clean_text(normalize_string(text))
                text_content += text + "\n"

        # pdfplumber를 사용한 표 추출
        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                tables = page.extract_tables()
                if tables:
                    text_content += "\n__table__\n"
                    for table in tables:
                        if table:
                            for row in table:
                                processed_row = []
                                for cell in row:
                                    if cell is None:
                                        processed_row.append(" ")  # 병합된 셀 처리
                                    else:
                                        cell_text = clean_text(normalize_string(str(cell).strip()))
                                        if "\n" in cell_text:
                                            cell_text = " ".join(cell_text.split())
                                        processed_row.append(cell_text)
                                row_text = " | ".join(processed_row)
                                text_content += row_text + "\n"
                    text_content += "__end_table__\n"
    except Exception as e:
        print(f"Error extracting text and tables from {pdf_path}: {e}")
    return text_content

class CustomPDFLoader:
    def __init__(self, file_path):
        self.file_path = file_path

    def load(self):
        documents = []
        try:
            # 텍스트와 표를 모두 추출
            text_content = extract_text_and_tables(self.file_path)

            # 메타데이터 생성 및 Document 객체로 변환
            metadata = {
                "source": self.file_path,
            }
            documents.append(Document(page_content=text_content, metadata=metadata))
        except Exception as e:
            print(f"Error loading PDF file {self.file_path}: {e}")
        return documents

def chunk_documents(documents):
    adjusted_documents = []
    for doc in documents:
        content = doc.page_content
        chunks = []
        
        # 표 구분자를 기준으로 분할
        table_sections = content.split("__table__")
        
        for section in table_sections:
            if "__end_table__" in section:
                table_content = section.split("__end_table__")[0]
                chunks.append(table_content)
            else:
                chunk_splitter = RecursiveCharacterTextSplitter(
                    chunk_size=1000,  # 텍스트 청크 크기를 키움
                    chunk_overlap=200,
                    separators=["\n\n", ".", "\n"]
                )
                normal_chunks = chunk_splitter.split_text(section)
                chunks.extend(normal_chunks)

        for chunk in chunks:
            adjusted_documents.append(Document(page_content=chunk, metadata=doc.metadata))
    
    return adjusted_documents

def format_docs(docs):
    context = ""
    for doc in docs:
        context += doc.page_content
        context += '\n\n'
    return context

def make_db(df):
    documents = []
    pdf_files = df['Source_path'].unique()

    # tqdm으로 파일 처리 진행 상황 표시
    with ThreadPoolExecutor() as executor:
        results = list(tqdm(executor.map(load_pdf_file, pdf_files), total=len(pdf_files), desc="Processing PDFs"))
    
    for result in results:
        documents.extend(result)
    
    # 정규화
    for doc in documents:
        doc.page_content = normalize_string(doc.page_content)
    
    # 표가 망가지지 않도록 청크 분할 처리
    chunks = chunk_documents(documents)
    print(f"Total number of chunks: {len(chunks)}")
    
    # FAISS DB 만들기 (메타데이터 포함)
    faiss = FAISS.from_documents(chunks, embedding=get_embedding())
    bm = BM25Retriever.from_documents(chunks)
    
    return faiss, bm

def load_pdf_file(pdf_file):
    try:
        pdf_loader = CustomPDFLoader(pdf_file)
        return pdf_loader.load()
    except Exception as e:
        print(f"Skipping corrupted file {pdf_file}: {e}")
        return []

# 데이터 로드
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# %%
def fewshot_db(df):
    df = df.drop('SAMPLE_ID', axis=1)
    df = df.drop('Source_path', axis=1)
    df = df.to_dict(orient='records')
    print("Loaded Fewshot Set:", len(df))
    to_vectorize = ["\n\n".join(normalize_string(value) for value in example.values()) for example in df]
    faiss = FAISS.from_texts(to_vectorize, embedding=get_embedding())
    # bm = BM25Retriever.from_texts(to_vectorize)
    # knn = KNNRetriever.from_texts(to_vectorize, embeddings=get_embedding())
    return faiss

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# %% [markdown]
# pypdf 이건 x
#
# 표가 많기 때문에
#
# PyMuPDFLoader 나 PDFPlumberLoader를 쓰고
#
# 표를 이미지로 불러오기도 하는데 이런경우 추가적인 전처리가 필요함

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

def format_docs(docs):
    """검색된 문서들을 하나의 문자열로 포맷팅"""
    context = ""
    for i, doc in enumerate(docs):
        #context += f"Document {i+1}\n"
        context += doc.page_content
        context += '\n\n'
    return context

# %%
# train_faiss_db, train_bm_retrievier, knn_retriever = make_db(train_df) 
# test_faiss_db, test_bm_retrievier, test_knn_retriever = make_db(test_df)
# fewshot_faiss_db, fewshot_bm_retrievier, fewshot_knn_retriever = fewshot_db(train_df)

# %%
# train_k = 1
# train_bm_retrievier.k = train_k
# knn_retriever.k = train_k
# faiss_retriever = train_faiss_db.as_retriever(search_kwargs={'k':train_k} )
# train_ensemble_retriever = EnsembleRetriever(
#     retrievers=[train_bm_retrievier,knn_retriever, faiss_retriever], weights=[0.3,0.3, 0.4]
# )

# test_k = 3
# test_bm_retrievier.k = test_k
# test_knn_retriever.k = test_k
# test_faiss_retriever = test_faiss_db.as_retriever(search_kwargs={'k':test_k} )
# test_ensemble_retriever = EnsembleRetriever(
#     retrievers=[test_bm_retrievier,test_knn_retriever, test_faiss_retriever], weights=[0.3,0.3, 0.4]
# )

# fewshot_k = 2
# fewshot_bm_retrievier.k = fewshot_k
# fewshot_knn_retriever.k = fewshot_k
# fewshot_faiss_retriever = fewshot_faiss_db.as_retriever(search_kwargs={'k':fewshot_k} )
# fewshot_ensemble_retriever = EnsembleRetriever(
#     retrievers=[fewshot_bm_retrievier,fewshot_knn_retriever, fewshot_faiss_retriever], weights=[0.3,0.3, 0.4]
# )

# %%
def setup_llm_pipeline(model_id = "meta-llama/Meta-Llama-3.1-8B-Instruct"):
    # 토크나이저 로드 및 설정
        # 양자화 설정 적용
    bnb_config = BitsAndBytesConfig(
    load_in_4bit=True, 
    bnb_4bit_use_double_quant=True, 
    bnb_4bit_quant_type="nf4", 
    bnb_4bit_compute_dtype=torch.bfloat16
    )
    model = AutoModelForCausalLM.from_pretrained(model_id, quantization_config=bnb_config,low_cpu_mem_usage=True)
    tokenizer = AutoTokenizer.from_pretrained(model_id)
    terminators = [
    tokenizer.eos_token_id,
    tokenizer.convert_tokens_to_ids("<|eot_id|>")
    ]

    text_generation_pipeline = pipeline(
        model=model,
        tokenizer=tokenizer,
        task="text-generation",
        return_full_text=False,
        temperature = 0.5,
        max_new_tokens=256,
        eos_token_id = terminators,
        pad_token_id = tokenizer.eos_token_id
    )

    llm = HuggingFacePipeline(pipeline=text_generation_pipeline)

    return llm
llm = setup_llm_pipeline()
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
def extract_answer(response):
    # AI: 로 시작하는 줄을 찾아 그 이후의 텍스트만 추출
    lines = response.split('\n')
    for line in lines:
        line = line.replace('**', '')
        if line.startswith('Answer:'):
            return line.replace('Answer:', '').strip()
        if line.startswith('assistant:'):
            return line.replace('assistant:', '').strip()
    return response.strip()  # AI: 를 찾지 못한 경우 전체 응답을 정리해서 반환

def fewshot_ex(fewshot_retriever, train_retriever, q, verbose=False):
    query = normalize_string(q)
    fewshot_results = fewshot_retriever.invoke(normalize_string(query)) #Document(page_content='중소벤처기업부_창업사업화지원\n\n창업사업화지원의 사업목적은 무엇인가?\n\n창업사업화지원의 사업목적은 창업기업의 성장단계별, 초격차 분야별, 글로벌화 지원체계를 구축‧운영하여 혁신 기술창업을 활성화하고 창업기업 성장 및 생존율 제고하는 것이다.')
    fewshot_str = ""
    i = 1
    for result in fewshot_results:
    
        result = result.page_content.split('\n\n')
        buff_str = f"<|start_header_id|>system<|end_header_id|>Example{i}\n<|eot_id|>\n\n"
        i+=1
        buff_str += "<|start_header_id|>user<|end_header_id|>\n"
        question = result[1]
        buff_str += f"Question\n{question}\n\n"
        if train_retriever is not None:
            buff_str += f"Context\n"
            docs = train_retriever.invoke(normalize_string(question))
            if verbose:
                print("Fewshot Q |",len(docs),"|",question)
            buff_str += format_docs(docs)
            buff_str += "<|eot_id|>\n\n"
        else: 
            buff_str += "<|eot_id|>\n\n"
            if verbose:
                print("Fewshot Q |",question)
        buff_str += f"<|start_header_id|>assistant<|end_header_id>\n{result[2]}<|eot_id|>"
        fewshot_str += buff_str    
        
    return fewshot_str

def run (train,test,fewshot,dataset,llm,verbose=False):
    results = []
    for i, row in (dataset.iterrows()):

        full_template = "<|begin_of_text|>"
        full_template += """<|start_header_id|>system<|end_header_id|>
You are the financial expert who helps me with my financial information Q&As.
You earn 10 points when you answer me and follow the rules and lose 7 points when you don't.
Please use contexts to answer the question.
Please your answers should be concise.
Please answers must be written in Korean.
Please answer in 1-3 sentences.
Answer like the question-answer examples given.
<|eot_id|>
"""
        question = row['Question']        
        if verbose:
            print(f"====={i}/{len(dataset)}{'='*255}")
            print("Question: ", question)
        
        fewshot_str = fewshot_ex(fewshot, train, question,verbose)
        full_template += fewshot_str
        full_template += """ """
        contexts = test.invoke(normalize_string(question))
        if verbose:
            print("Context Number|",len(contexts),end="|")
        contexts = format_docs(contexts)
        full_template += """<|start_header_id|>user<|end_header_id|>\nQuestion\n{input}\n\n"""
        full_template += f"""Context\n{contexts}<|eot_id|>\n\n"""
        full_template += """<|start_header_id|>assistant<|end_header_id>\n"""
        
        prompt = PromptTemplate.from_template(full_template)
        qa_chain = (
        {
            "input": RunnablePassthrough(),
        }
        | prompt
        | llm
        | StrOutputParser()
        )

        answer = qa_chain.invoke(input=question)
        answer = extract_answer(answer)
        results.append({
            "Question": question,
            "Answer": answer,
            "Source": row['Source']
        })
        if verbose:
            print("=====Answer=====\n", results[-1]['Answer'])
            try:
                print("=====REAL Answer=====\n",row['Answer'])
            except:
                pass
    return results

# %%
from collections import Counter
def calculate_f1_score(true_sentence, predicted_sentence, sum_mode=True):

    #공백 제거
    true_sentence = ''.join(true_sentence.split())
    predicted_sentence = ''.join(predicted_sentence.split())
    
    true_counter = Counter(true_sentence)
    predicted_counter = Counter(predicted_sentence)

    #문자가 등장한 개수도 고려
    if sum_mode:
        true_positive = sum((true_counter & predicted_counter).values())
        predicted_positive = sum(predicted_counter.values())
        actual_positive = sum(true_counter.values())

    #문자 자체가 있는 것에 focus를 맞춤
    else:
        true_positive = len((true_counter & predicted_counter).values())
        predicted_positive = len(predicted_counter.values())
        actual_positive = len(true_counter.values())

    #f1 score 계산
    precision = true_positive / predicted_positive if predicted_positive > 0 else 0
    recall = true_positive / actual_positive if actual_positive > 0 else 0
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    
    return precision, recall, f1_score

def calculate_average_f1_score(true_sentences, predicted_sentences):
    
    total_precision = 0
    total_recall = 0
    total_f1_score = 0
    
    for true_sentence, predicted_sentence in zip(true_sentences, predicted_sentences):
        precision, recall, f1_score = calculate_f1_score(true_sentence, predicted_sentence)
        total_precision += precision
        total_recall += recall
        total_f1_score += f1_score
    
    avg_precision = total_precision / len(true_sentences)
    avg_recall = total_recall / len(true_sentences)
    avg_f1_score = total_f1_score / len(true_sentences)
    
    return {
        'average_precision': avg_precision,
        'average_recall': avg_recall,
        'average_f1_score': avg_f1_score
    }

# %%
# from sklearn.model_selection import KFold
# import copy

# weight = [0.5,0.5]
# train_faiss_db, train_bm_retrievier = make_db(train_df) 

# train_k = 1
# train_bm_retrievier.k = train_k
# #knn_retriever.k = train_k
# train_faiss_retriever = train_faiss_db.as_retriever(search_type="mmr",search_kwargs={'k':train_k} )
# train_ensemble_retriever = EnsembleRetriever(
#     retrievers=[train_bm_retrievier, train_faiss_retriever], weights=weight
# )

# test_bm_retrievier = copy.deepcopy(train_bm_retrievier)
# test_k = 2
# test_bm_retrievier.k = test_k
# #test_knn_retriever.k = test_k
# test_faiss_retriever = train_faiss_db.as_retriever(search_type="mmr",search_kwargs={'k':test_k} )
# test_ensemble_retriever = EnsembleRetriever(
#     retrievers=[test_bm_retrievier, test_faiss_retriever], weights=weight
# )

# fewshot_k = 3

# k_folds = 4
# fold_results = []
# kf = KFold(n_splits=k_folds, shuffle=True, random_state=52)
# for fold, (train_index, val_index) in enumerate(kf.split(train_df)):
#     fold_result = []
#     train_set = train_df.iloc[train_index]
#     val_set = train_df.iloc[val_index]
    
    
#     fewshot_faiss_db = fewshot_db(train_set)
#     fewshot_faiss_retriever = fewshot_faiss_db.as_retriever(search_kwargs={'k':fewshot_k} )

#     pred = run(train_ensemble_retriever, test_ensemble_retriever, fewshot_faiss_retriever, val_set, llm, verbose=True)
#     result = pd.DataFrame()
#     result['pred'] = [result['Answer'] for result in pred]
#     val_set.index = range(len(val_set))
#     result['gt'] = val_set['Answer']
        
#     result = calculate_average_f1_score(result['gt'], result['pred'])
#     print(result)
#     fold_results.append(result)
#     break
# Out:
# Processing PDFs: 100%|██████████| 16/16 [03:45<00:00, 14.10s/it]
# Total number of chunks: 1948
# c:\ProgramData\anaconda3\envs\llm_project\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Loaded Fewshot Set: 372
# c:\ProgramData\anaconda3\envs\llm_project\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# =====1/124===============================================================================================================================================================================================================================================================
# Question:  2024년 중앙정부의 예산 지출은 어떻게 구성되어 있나요?
# Fewshot Q | 2 | 2024년 중앙정부 재정체계는 어떻게 구성되어 있나요?
# Fewshot Q | 1 | 국가교육위원회의 '24년 예산은 얼마인가?
# Fewshot Q | 2 | 2024년도 예산수입은 어떻게 구성되어 있나요?
# Context Number| 4|
# c:\ProgramData\anaconda3\envs\llm_project\Lib\site-packages\transformers\models\llama\modeling_llama.py:660: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(
# =====Answer=====
#  2024년 중앙정부의 예산 지출은 일반회계 356.5조원, 특별회계 81.7조원으로 구성되어 있습니다.
# =====REAL Answer=====
#  2024년 중앙정부의 예산 지출은 일반회계 356.5조원, 21개 특별회계 81.7조원으로 구성되어 있습니다.
# =====4/124===============================================================================================================================================================================================================================================================
# Question:  2024년 총수입은 얼마이며, 예산수입과 기금수입은 각각 몇 조원인가요?
# Fewshot Q | 2 | 2024년도 총계 기준 재정규모는 얼마이며, 예산과 기금은 각각 몇 조원으로 구성되어 있는가?
# Fewshot Q | 2 | 2024년도 예산수입은 어떻게 구성되어 있나요?
# Fewshot Q | 2 | 2024년 국세수입은 얼마이며, 일반회계와 특별회계의 규모는 각각 얼마인가요?
# Context Number| 4|=====Answer=====
#  2024년 총수입은 612.2조원이며, 예산수입은 395.5조원, 기금수입은 216.7조원입니다.
# =====REAL Answer=====
#  2024년 총수입은 612.2조원이며, 예산수입은 395.5조원, 기금수입은 216.7조원입니다.
# =====6/124===============================================================================================================================================================================================================================================================
# Question:  2024년의 기금수입은 어떻게 구성되어 있나요?
# Fewshot Q | 2 | 2024년 기금수입 중 가장 큰 비중을 차지하는 항목은 무엇인가?
# Fewshot Q | 2 | 2024년도 예산수입은 어떻게 구성되어 있나요?
# Fewshot Q | 2 | 2024년 중앙정부 재정체계는 어떻게 구성되어 있나요?
# Context Number| 4|=====Answer=====
#  2024년 기금수입은 26.6조원으로 구성되어 있으며, 재화 및 용역판매수입 2.6%, 재산수입 2.8%, 관유물매각대 1.1%, 융자 및 전대차관원금회수 1.3%, 차입금 및 여유자금회수 0.03%, 기업특별회계 영업수입 6.9%, 경상이전수입 10.6%로 구성되어 있습니다.
# =====REAL Answer=====
#  2024년도 기금수입은 사회보장성기금 92.3조원, 경상이전수입 39.6조원, 기타 84.7조원으로 구성되어 있습니다.
# =====11/124===============================================================================================================================================================================================================================================================
# Question:  2024년 총지출 기준 예산의 일반회계와 특별회계의 비중이 각각 얼마인가?
# Fewshot Q | 2 | 2024년 국세수입은 얼마이며, 일반회계와 특별회계의 규모는 각각 얼마인가요?
# Fewshot Q | 2 | 2024년도 예산수입은 어떻게 구성되어 있나요?
# Fewshot Q | 2 | 2024년 중앙정부 재정체계는 어떻게 구성되어 있나요?
# Context Number| 4|=====Answer=====
#  2024년 예산의 일반회계와 특별회계의 비중은 일반회계 79.4%, 특별회계 18.6%입니다.
# =====REAL Answer=====
#  2024년 총지출 중 일반회계와 특별회계의 비중은 각각 54.3%와 12.4%이다.
# =====19/124===============================================================================================================================================================================================================================================================
# Question:  2020년 결산 기준, 연구개발비 중 개발연구 규모는 몇 억원인가?
# Fewshot Q | 2 | 산업혁신지원 부문 주요 변동 내역에서 어떤 부문의 기술개발 예산이 가장 크게 증가하였으며, 그 증가율은 얼마인가?
# Fewshot Q | 2 | 정부는 어떤 분야에 R&D 투자를 집중할 계획인가?
# Fewshot Q | 1 | 전략목표 중 원자력·방사선·핵비확산 분야의 기술적 역량 강화를 통한 안전한 원자력 이용 추구 및 국가 핵안보 체제 선진화 프로그램목표의 '24년 예산은 얼마인가?
# Context Number| 3|=====Answer=====
#  2020년 결산 기준, 연구개발비 중 개발연구 규모는 97억원입니다.
# =====REAL Answer=====
#  2020년 결산 기준 연구개발비 중 개발연구 규모는 78754억원이다.
# =====20/124===============================================================================================================================================================================================================================================================
# Question:  세출예산현액이란?
# Fewshot Q | 2 | 일반회계 세출은 어떠한 목적을 위해 사용되는가?
# Fewshot Q | 2 | 예산순계란 무엇인가?
# Fewshot Q | 2 | 특별회계란 무엇인가?
# Context Number| 4|=====Answer=====
#  세출예산현액은 다음 회계연도에 예산안에서 편성된 예산의 지출을 의미합니다.
# =====REAL Answer=====
#  예산 확정 후 전년도로부터의 이월액 반영, 추경 편성, 기금운용계획 변경, 이용・전용, 예비비 증액 등을 반영한 것으로, 실제 지출할 수 있는 한도액을 의미한다.
# =====23/124===============================================================================================================================================================================================================================================================
# Question:  2022년 기준, 일반회계, 특별회계, 기금의 집행률은?
# Fewshot Q | 2 | 2022년 기준, 일반회계와 기타특별회계의 이월금 차지 비율은 얼마인가?
# Fewshot Q | 2 | 2017년부터 2022년까지의 사업성기금의 연도별 이월금 규모 추이는 어떠한가?
# Fewshot Q | 2 | 2022년 기준, 국가 재무제표상 부채는 얼마이며, 이는 어떻게 구성되어 있는가?
# Context Number| 4|=====Answer=====
#  2022년 기준, 일반회계, 특별회계, 기금의 집행률은 각각 97.3%, 94.7%, 97.6%로 나타났습니다.
# =====REAL Answer=====
#  2022년 기준, 집행률은 일반회계 97.3%, 특별회계 94.7%, 기금 97.6%
# =====25/124===============================================================================================================================================================================================================================================================
# Question:  2022년 결산 기준으로 사회보험성기금의 이월금 규모는 몇 억원인가요?
# Fewshot Q | 2 | 2017년부터 2022년까지의 사업성기금의 연도별 이월금 규모 추이는 어떠한가?
# Fewshot Q | 2 | 2022년 기준, 일반회계와 기타특별회계의 이월금 차지 비율은 얼마인가?
# Fewshot Q | 2 | 2022년 기준, 국가 재무제표상 부채는 얼마이며, 이는 어떻게 구성되어 있는가?
# Context Number| 4|=====Answer=====
#  2022년 기준, 사회보험성기금의 이월금은 1,679억원으로, 전체 이월금의 34.5%를 차지하였다.
# =====REAL Answer=====
#  223억원입니다.
# =====27/124===============================================================================================================================================================================================================================================================
# Question:  2022년 기준으로 국내총생산 대비 일반정부부채와 공공부문 부채의 비중은 각각 몇 퍼센트인가?
# Fewshot Q | 2 | 2022년 기준, 국가 재무제표상 부채는 얼마이며, 이는 어떻게 구성되어 있는가?
# Fewshot Q | 2 | 2022년 기준, 일반회계와 기타특별회계의 이월금 차지 비율은 얼마인가?
# Fewshot Q | 2 | 국가채무의 산출 기준은?
# Context Number| 4|=====Answer=====
#  2022년 기준, 국내총생산 대비 일반정부부채는 49.4%, 공공부문 부채는 52.5%로 나타났습니다.
# =====REAL Answer=====
#  일반정부부채(D2)는 53.5%, 공공부문 부채(D3)는 73.5%이다.
# =====37/124===============================================================================================================================================================================================================================================================
# Question:  2007년 시행된 국가재정법에서 추경 편성 사유로 명시된 사항은 무엇인가?
# Fewshot Q | 2 | 추가경정예산이란 무엇이며, 언제 편성되나요?
# Fewshot Q | 2 | 추가경정예산이란 무엇을 의미하는가?
# Fewshot Q | 2 | 추가경정예산은 2008년 이후 몇 번의 추가경정예산이 편성되었는가?
# Context Number| 3|=====Answer=====
#  ①전쟁이나 대규모 재해가 발생한 경우, ②경기침체, 대량 실업, 남북 관계의 변화, 경제협력과 같은 대내외 여건에 중대한 변화가 발생하였거나 발생할 우려가 있는 경우, ③법령에 따라 국가가 지급하여야 하는 지출이 발생하거나 증가하는 경우
# =====REAL Answer=====
#  국가재정법에서 추경 편성 사유로 명시된 사항은 전쟁이나 대규모 재해가 발생한 경우, 경기침체, 대량 실업, 남북 관계의 변화, 경제협력과 같은 대내외 여건에 중대한 변화가 발생하였거나 발생할 우려가 있는 경우, 법령에 따라 국가가 지급하여야 하는 지출이 발생하거나 증가하는 경우에 한정되어 있습니다.
# =====41/124===============================================================================================================================================================================================================================================================
# Question:  2024년 교육재정 교부금의 규모는 얼마이고, 전년 대비 추이는 어떠한가?
# Fewshot Q | 1 | 국가교육위원회의 '24년 예산은 얼마인가?
# Fewshot Q | 2 | 2024년도 예산수입은 어떻게 구성되어 있나요?
# Fewshot Q | 2 | 교육 분야 재정투자 계획에 따르면 고등교육 분야의 예산은 2024년에 어떻게 변화하는가?
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Context Number| 4|=====Answer=====
#  2024년 교육재정 교부금의 규모는 109.1조원으로, 2023년 대비 6.6% 증가한다.
# =====REAL Answer=====
#  2024년 교육재정교부금은 73.0조원이며 전년 대비 8.9% 감소하였다.
# =====43/124===============================================================================================================================================================================================================================================================
# Question:  2024년에 교육재정교부금에서 유아교육비 및 보육료 지원에 할당된 비중은?
# Fewshot Q | 2 | 교육 분야 재정투자 계획에 따르면 고등교육 분야의 예산은 2024년에 어떻게 변화하는가?
# Fewshot Q | 2 | 2024년 정부 예산안에서 출산·양육 부담 경감을 위해 어떤 정책이 시행되고 있는가?
# Fewshot Q | 2 | 평생·직업교육 부문 주요 변동내역에서 평생교육바우처지원 예산은 2023년 대비 2024년에 얼마나 증가했는가?
# Context Number| 4|=====Answer=====
#  유아교육비 및 보육료 지원에 할당된 교육재정교부금의 비중은 2024년 34.9%이다.
# =====REAL Answer=====
#  4.40%
# =====44/124===============================================================================================================================================================================================================================================================
# Question:  교육재정 교부금이란?
# Fewshot Q | 2 | 지방교부세는 어떤 목적을 위해 자치단체에 교부되는 재원인가?
# Fewshot Q | 2 | 일반회계 세출은 어떠한 목적을 위해 사용되는가?
# Fewshot Q | 2 | 세입예산은 어떻게 분류되는가?
# Context Number| 4|=====Answer=====
#  교육재정 교부금은 지방자치단체에 교육부문 예산을 지원하는 재원이다.
# =====REAL Answer=====
#  교육의 균형발전을 위해 교육기관 및 교육행정기관 경비를 국가가 교부하는 일반지원금으로, 일반회계 보통・특별교부금, 고교 무상교육 증액분, 특별회계 유아교육비・보육료 지원 교부금 등 4가지로 구성되었다.
# =====46/124===============================================================================================================================================================================================================================================================
# Question:  특별회계 국고보조금 중 국가균형발전특별회계에서 얼마가 포괄보조금으로 지출되는가?
# Fewshot Q | 2 | 일반회계 세출은 어떠한 목적을 위해 사용되는가?
# Fewshot Q | 2 | 사회보장성기금수지 산출 시 어떤 기금을 대상으로 하는가?
# Fewshot Q | 2 | 지방교부세와 국고보조금의 차이는 무엇인가요?
# Context Number| 4|=====Answer=====
#  국가균형발전특별회계에서 10.0조원이 포괄보조금으로 지출됩니다.
# =====REAL Answer=====
#  특별회계 국고보조금 18.2조원 중 10.0조원이 국가균형발전특별회계에서 지출되는 포괄보조금이다.
# =====47/124===============================================================================================================================================================================================================================================================
# Question:  2024년의 국고보조사업(자치단체 이전)에서 기금 규모는 얼마인가?
# Fewshot Q | 2 | 2024년 중앙정부 재정체계는 어떻게 구성되어 있나요?
# Fewshot Q | 2 | 2024년도 총계 기준 재정규모는 얼마이며, 예산과 기금은 각각 몇 조원으로 구성되어 있는가?
# Fewshot Q | 2 | 2024년 국세수입은 얼마이며, 일반회계와 특별회계의 규모는 각각 얼마인가요?
# Context Number| 4|=====Answer=====
#  2024년 기금 규모는 1,023.3조원이며, 국고보조사업(자치단체 이전)은 89.3조원입니다.
# =====REAL Answer=====
#  90,247억원으로 10.1%를 차지하고 있다.
# =====52/124===============================================================================================================================================================================================================================================================
# Question:  임신·출산을 희망하는 가구에 어떤 지원이 신규로 이뤄지고 있으며, 고위험 임산부와 미숙아·선천성 이상아의 의료비 지원은 어떻게 이루어지는가?
# Fewshot Q | 2 | 2024년 정부 예산안에서 출산·양육 부담 경감을 위해 어떤 정책이 시행되고 있는가?
# Fewshot Q | 2 | 2024년도 예산안에서 돌봄부담 완화를 위해 어떤 조치가 취해졌는가?
# Fewshot Q | 2 | 최중증 발달장애인을 위한 돌봄 체계 구축을 위해 어떤 변화가 있었나요?
# Context Number| 4|=====Answer=====
#  고위험 임산부와 미숙아·선천성 이상아의 의료비 지원은 소득수준에 관계없이 지원되며, 난임가구에 필수가임력(생식건강) 검진비와 냉동난자를 활용한 보조 생식술 비용이 신규로 지원된다.
# =====REAL Answer=====
#  임신·출산을 희망하는 가구에는 필수가임력(생식건강) 검진비와 냉동난자를 활용한 보조 생식술 비용을 신규로 지원하며, 고위험 임산부와 미숙아·선천성 이상아의 의료비는 소득수준에 관계없이 지원된다.
# =====57/124===============================================================================================================================================================================================================================================================
# Question:  2024년 R&D 분야에 대한 재정투자 규모는 2023년 대비 얼마나 감소했으며, 어떤 분야의 국가전략기술 투자를 확대할 계획인가?
# Fewshot Q | 2 | 정부는 어떤 분야에 R&D 투자를 집중할 계획인가?
# Fewshot Q | 2 | 2024년 R&D 분야 재정투자 계획 중 가장 큰 감소율을 보이는 분야는 무엇인가?
# Fewshot Q | 2 | R&D 분야의 예산은 '23년 대비 '24년 어떻게 변했나요?
# Context Number| 3|=====Answer=====
#  2024년 R&D 분야에 대한 재정투자 규모는 2023년 대비 9.5% 감소한 26.5조원이며, AI, 첨단바이오, 양자 등 국가전략기술 투자를 확대할 계획입니다.
# =====REAL Answer=====
#  2024년 R&D 분야에 대한 재정투자 규모는 2023년 대비 9.5% 감소한 26.5조원이며, AI·바이오·반도체 등의 분야에 대한 국가전략기술 투자를 확대할 계획입니다.
# =====58/124===============================================================================================================================================================================================================================================================
# Question:  우주산업 클러스터 삼각체제 구축사업의 목표와 국가 우주산업 육성 거점 지역은 어디인가?
# Fewshot Q | 2 | 정부는 어떤 분야에 R&D 투자를 집중할 계획인가?
# Fewshot Q | 1 | 전략목표 중 원자력·방사선·핵비확산 분야의 기술적 역량 강화를 통한 안전한 원자력 이용 추구 및 국가 핵안보 체제 선진화 프로그램목표의 '24년 예산은 얼마인가?
# Fewshot Q | 2 | 세계 최고 수준의 네트워크 인프라 환경을 구축하기 위해 어떤 방식으로 투자가 확대되고 있는가?
# Context Number| 3|=====Answer=====
#  국가 우주산업 육성 거점 지역은 전남, 경남, 대전으로 우주경제 시대 대비 민간 주도 우주개발 역량 강화 및 자생적 생태계 조성을 위해 핵심 인프라를 구축하는 플래그십 프로젝트이다.
# =====REAL Answer=====
#  우주산업 클러스터 삼각체제 구축사업은 우주경제 시대 대비 민간 주도 우주개발 역량 강화 및 자생적 생태계 조성을 위해 핵심 인프라를 구축하는 플래그십 프로젝트이며, 전남, 경남, 대전을 국가 우주산업 육성 거점으로 지정했다.
# =====62/124===============================================================================================================================================================================================================================================================
# Question:  2024년도 공공질서 및 안전 분야의 재정투자는 전년도 대비 어떻게 변화했으며, 어떤 분야에 특히 재정투자가 집중되었는가?
# Fewshot Q | 2 | 문화·체육·관광분야 재정투자 계획에서 2023년 대비 2024년에 예산이 증가한 분야는 무엇인가요?
# Fewshot Q | 2 | 물환경 부문 주요 변동내역에서 하수처리수 재이용 사업 예산은 2023년 대비 2024년에 얼마나 변화하였는가?
# Fewshot Q | 2 | 재정투자 계획에 따르면 농업·농촌 분야의 예산이 2023년에 비해 2024년에 얼마나 변화하는가?
# Context Number| 4|=====Answer=====
#  2024년 공공질서 및 안전 분야의 재정투자는 24.4조원으로 2023년 22.9조원보다 6.5% 증가하였다.
# =====REAL Answer=====
#  2024년도 공공질서 및 안전 분야의 재정투자는 24.4조원으로 2023년도 22.9조원 대비 6.5% 증가하였으며, 마약·스토킹 등 민생침해범죄 예방·대응과 재난·안전 사고에 대한 근본적 예방에 집중적으로 투자하였다.
# =====77/124===============================================================================================================================================================================================================================================================
# Question:  예산 증감률이 가장 높은 분야는 무엇인가요?
# Fewshot Q | 2 | 예산총계란 무엇을 말하나요?
# Fewshot Q | 2 | 2024년도 예산안에서 세외수입 중 가장 큰 규모를 차지하는 세입항목은 무엇인가?
# Fewshot Q | 2 | 기금의 경우 특정 항목의 지출 금액을 얼마 이상 변경할 때 국회의 의결이 필요한가, 그리고 예산과 기금의 차이점은 무엇인가?
# Context Number| 4|=====Answer=====
#  사회복지 분야
# =====REAL Answer=====
#  외교·통일 분야가 17.7%로 예산 증감률이 가장 높습니다.
# =====98/124===============================================================================================================================================================================================================================================================
# Question:  하수관로정비 사업 예산은 2023년 대비 2024년에 얼마나 증가했는가?
# Fewshot Q | 2 | 물환경 부문 주요 변동내역에서 하수처리수 재이용 사업 예산은 2023년 대비 2024년에 얼마나 변화하였는가?
# Fewshot Q | 2 | 문화·체육·관광분야 재정투자 계획에서 2023년 대비 2024년에 예산이 증가한 분야는 무엇인가요?
# Fewshot Q | 2 | 물환경 부문 주요 변동내역에서 하수처리장 설치사업 예산은 2023년 대비 2024년에 얼마나 증가했는가?
# Context Number| 3|=====Answer=====
#  하수관로정비 사업 예산은 2023년 9,531억원에서 2024년 1조 2,816억원으로 34.5% 증가하였다.
# =====REAL Answer=====
#  하수관로정비 사업 예산은 2023년 9,531억원에서 2024년 1조 2,816억원으로 증가하여 34.5% 증가하였다.
# =====103/124===============================================================================================================================================================================================================================================================
# Question:  국회의 입법활동 및 의정활동을 지원하기 위해 어떤 활동들이 실시되고 있는가?
# Fewshot Q | 1 | 예산안 심의란 무엇을 하는 과정인가요?
# Fewshot Q | 2 | 생계급여 사업에서 기초생활보장관리를 위해 어떤 활동을 추진하고 있는가?
# Fewshot Q | 2 | 기금의 경우 특정 항목의 지출 금액을 얼마 이상 변경할 때 국회의 의결이 필요한가, 그리고 예산과 기금의 차이점은 무엇인가?
# Context Number| 4|=====Answer=====
#  국회의 입법활동 및 의정활동을 지원하기 위해 국회 정책세미나·토론회·간담회 실시간 생중계 시스템 구축, SNS 영상 제작 지원, 의정활동 안내 문자메시지 발송, 국회사무처운영, 국회도서관운영, 예산정책처운영, 입법조사처운영, 국무총리실 행정지원 등 다양한 활동이 실시되고 있습니다.
# =====REAL Answer=====
#  국회 정책세미나·토론회·간담회 실시간 생중계 시스템 구축, SNS 영상 제작 지원 및 의정활동 안내 문자메시지 발송 등을 통해 국회 입법활동 및 의정활동을 지원하고 있다.
# =====108/124===============================================================================================================================================================================================================================================================
# Question:  국가첨단전략산업 특화단지에 대한 지원 계획은 어떻게 되어 있는가?
# Fewshot Q | 2 | 정부는 어떤 분야에 R&D 투자를 집중할 계획인가?
# Fewshot Q | 2 | 어떤 전략에 따라 4차산업혁명 분야와 비대면 분야가 중점 육성산업으로 선정되었나요?
# Fewshot Q | 2 | 창업사업화지원의 사업목적은 무엇인가?
# Context Number| 4|=====Answer=====
#  국가첨단전략산업 특화단지에 대한 지원 계획은 전력·용수 등 핵심 기반시설에 대한 국비 지원을 신설하고, 기술 실증 및 상용화 촉진을 위한 저리 융자를 신설하는 등 첨단산업 인프라·인력양성 투자 확대를 통해 반도체 등 국가첨단전략산업을 지원합니다.
# =====REAL Answer=====
#  국가첨단전략산업 특화단지에 대한 저리융자, 기반시설 구축, 현장 맞춤형 실무교육 등을 종합적으로 지원할 계획이다.
# =====109/124===============================================================================================================================================================================================================================================================
# Question:  가족돌봄청년을 위해 신규로 지원되는 혜택은 무엇인가요?
# Fewshot Q | 2 | 2024년도 예산안에서 돌봄부담 완화를 위해 어떤 조치가 취해졌는가?
# Fewshot Q | 2 | 일반 청년을 위해 어떤 종합적인 지원이 제공되고 있는가?
# Fewshot Q | 2 | 최중증 발달장애인을 위한 돌봄 체계 구축을 위해 어떤 변화가 있었나요?
# Context Number| 4|=====Answer=====
#  가족돌봄청년을 위해 신규로 지원되는 혜택으로는 가족돌봄청년의 교육비 지원, 양육비 지원, 장학금 지원 등이 있습니다.
# =====REAL Answer=====
#  자기돌봄비(연200만원)와 돌봄코디네이터를 통한 밀착 사례관리 및 자조모임 등을 신규로 지원한다.
# =====110/124===============================================================================================================================================================================================================================================================
# Question:  의료 분야에 대한 국고 지원이 어떻게 확대되고 있는가?
# Fewshot Q | 2 | 보건복지부의 생계급여지원 사업은 국고보조율의 비중이 어떻게 되나요?
# Fewshot Q | 2 | 교통약자의 이동편의를 증진하기 위해 어떤 사업을 확대하고 지속적으로 지원할 것인가?
# Fewshot Q | 2 | 대학의 일반재정지원을 확대하는 이유와 국립대학 및 사립대학의 투자 확대 방식은 무엇인가?
# Context Number| 4|=====Answer=====
#  의료 분야에 대한 국고 지원은 건강보험과 노인장기요양보험에 대한 국고지원을 확대하고, 취약계층 의료기반 확충을 위해 암검진비 지원, 재활병원 건립 등에 투자한다.
# =====REAL Answer=====
#  달빛어린이병원(45개소)에 대해 국고 지원에 착수하고, 소아환자에게 24시간 의료상담을 제공하는 24시간 상담센터를 신설하고, 어린이 공공전문진료센터와 소아암 전문거점병원을 확충하고, 전공의 수련수당도 신규 지원하고 있다.
# =====113/124===============================================================================================================================================================================================================================================================
# Question:  2023년 기획재정부의 총세입예산은 얼마인가요?
# Fewshot Q | 2 | 2023년 예산안을 기준으로 재정융자 규모는 얼마이며, 총지출 대비 어느 정도를 차지하나요?
# Fewshot Q | 2 | 2023년도 국방 분야의 예산 중 가장 큰 금액이 할당된 세부 항목은 무엇인가요?
# Fewshot Q | 2 | 총사업비 관리대상사업의 규모는 2023년 몇 조원이며, 전년 대비 얼마나 증가했나요?
# Context Number| 4|=====Answer=====
#  2023년 기획재정부의 총세입예산은 1,004조원입니다.
# =====REAL Answer=====
#  438,715,377백만원
# =====114/124===============================================================================================================================================================================================================================================================
# Question:  기초생활보장제도 4대 급여의 예산 규모는 2023년 대비 2024년에 어떻게 변화되는가?
# Fewshot Q | 2 | 재정투자 계획에 따르면 농업·농촌 분야의 예산이 2023년에 비해 2024년에 얼마나 변화하는가?
# Fewshot Q | 2 | 문화·체육·관광분야 재정투자 계획에서 2023년 대비 2024년에 예산이 증가한 분야는 무엇인가요?
# Fewshot Q | 2 | 물환경 부문 주요 변동내역에서 하수처리수 재이용 사업 예산은 2023년 대비 2024년에 얼마나 변화하였는가?
# Context Number| 3|=====Answer=====
#  기초생활보장제도 4대 급여의 예산 규모는 2023년 17.8조원에서 2024년 19.4조원으로 9.2% 증가한다.
# =====REAL Answer=====
#  2023년 17.8조원에서 2024년 19.4조원으로 확대된다.
# =====120/124===============================================================================================================================================================================================================================================================
# Question:  교육 분야 재정투자 계획에 따르면 2024년에 유아및초중등교육 분야의 예산이 2023년에 비해 어떻게 변하는가?
# Fewshot Q | 2 | 교육 분야 재정투자 계획에 따르면 고등교육 분야의 예산은 2024년에 어떻게 변화하는가?
# Fewshot Q | 2 | 재정투자 계획에 따르면 농업·농촌 분야의 예산이 2023년에 비해 2024년에 얼마나 변화하는가?
# Fewshot Q | 2 | 문화·체육·관광분야 재정투자 계획에서 2023년 대비 2024년에 예산이 증가한 분야는 무엇인가요?
# Context Number| 3|=====Answer=====
#  유아 및 초중등교육 부문 예산은 2024년 73조 7,290억원으로 2023년 대비 8.9% 감소한다.
# =====REAL Answer=====
#  2024년에 유아및초중등교육 분야의 예산은 737,290억원으로 2023년 대비 8.9% 감소한다.
# =====125/124===============================================================================================================================================================================================================================================================
# Question:  문화예술 부문의 총 예산은 어떻게 변화했는가?
# Fewshot Q | 2 | 2017년부터 2022년까지의 사업성기금의 연도별 이월금 규모 추이는 어떠한가?
# Fewshot Q | 2 | 산업혁신지원 부문 주요 변동 내역에서 어떤 부문의 기술개발 예산이 가장 크게 증가하였으며, 그 증가율은 얼마인가?
# Fewshot Q | 2 | 예산총계란 무엇을 말하나요?
# Context Number| 4|=====Answer=====
#  문화예술 부문의 총 예산은 2023년 1조 4천억원에서 2024년 1조 1천억원으로 감소하였다.
# =====REAL Answer=====
#  문화예술 부문의 총 예산은 2023년 40,022억원에서 2024년 40,628억원으로 1.5% 증가하였다.
# =====127/124===============================================================================================================================================================================================================================================================
# Question:  2024년에 산업혁신지원 부문의 총 예산은 얼마이며, 전년 대비 어떤 증감률을 보였는가?
# Fewshot Q | 2 | 산업혁신지원 부문 주요 변동 내역에서 어떤 부문의 기술개발 예산이 가장 크게 증가하였으며, 그 증가율은 얼마인가?
# Fewshot Q | 2 | 문화·체육·관광분야 재정투자 계획에서 2023년 대비 2024년에 예산이 증가한 분야는 무엇인가요?
# Fewshot Q | 1 | 국가교육위원회의 '24년 예산은 얼마인가?
# Context Number| 4|=====Answer=====
#  2024년 산업혁신지원 부문의 총 예산은 6,500억원이며, 전년 대비 48.6% 증가했습니다.
# =====REAL Answer=====
#  2024년에 산업혁신지원 부문의 총 예산은 63,146억원이며, 전년 대비 5.1% 증가하였다.
# =====129/124===============================================================================================================================================================================================================================================================
# Question:  산업혁신지원 부문 주요 변동 내역에서 2024년에 산업혁신인재성장지원 부문의 예산은 얼마이며, 전년 대비 어떤 증감률을 보였는가?
# Fewshot Q | 2 | 산업혁신지원 부문 주요 변동 내역에서 어떤 부문의 기술개발 예산이 가장 크게 증가하였으며, 그 증가율은 얼마인가?
# Fewshot Q | 2 | 문화·체육·관광분야 재정투자 계획에서 2023년 대비 2024년에 예산이 증가한 분야는 무엇인가요?
# Fewshot Q | 2 | 2024년 대통령비서실 및 국가안보실의 성과관리대상 사업의 재정현황 중 인건비의 비율은 얼마인가?
# Context Number| 4|=====Answer=====
#  2024년 산업혁신인재성장지원 부문의 예산은 1,575억원이며, 전년 대비 16% 증가했습니다.
# =====REAL Answer=====
#  2024년에 산업혁신인재성장지원 부문의 예산은 1,575억원이며, 전년 대비 16.0% 증가하였다.
# =====136/124===============================================================================================================================================================================================================================================================
# Question:  외교·통일 분야 재정투자 계획에서 2024년 외교·통상 부문 예산은 2023년 대비 얼마나 증가했는가?
# Fewshot Q | 2 | 문화·체육·관광분야 재정투자 계획에서 2023년 대비 2024년에 예산이 증가한 분야는 무엇인가요?
# Fewshot Q | 2 | 무역 및 투자유치 부문 주요 변동내역에서 2024년 외국인투자 현금지원이 작년 대비 얼마나 증가했는가?
# Fewshot Q | 2 | 재정투자 계획에 따르면 농업·농촌 분야의 예산이 2023년에 비해 2024년에 얼마나 변화하는가?
# Context Number| 4|=====Answer=====
#  29.8% 증가했다.
# =====REAL Answer=====
#  14,736억원 증가하여 29.8% 증가하였다.
# =====137/124===============================================================================================================================================================================================================================================================
# Question:  재정투자 계획에서 2023년 대비 2024년에 가장 큰 증가율을 보인 분야는 무엇인가요?
# Fewshot Q | 2 | 문화·체육·관광분야 재정투자 계획에서 2023년 대비 2024년에 예산이 증가한 분야는 무엇인가요?
# Fewshot Q | 2 | 재정투자 계획에 따르면 농업·농촌 분야의 예산이 2023년에 비해 2024년에 얼마나 변화하는가?
# Fewshot Q | 2 | 국고보조사업 규모는 2024년에 얼마이며 전년 대비 어떤 증가율을 보이는가?
# Context Number| 4|=====Answer=====
#  2024년에 가장 큰 증가율을 보인 분야는 사회복지 분야로 64.3%의 비중을 차지하여 26조 8,963억원의 융자 규모를 보였다.
# =====REAL Answer=====
#  2023년 대비 2024년에 22.1%의 증가율을 보인 재정·금융 분야입니다.
# =====145/124===============================================================================================================================================================================================================================================================
# Question:  예산 사전의결의 원칙은 무엇인가?
# Fewshot Q | 2 | 예산편성 시 어떤 원칙을 따라 편성 예비비 사용이 이루어지는가?
# Fewshot Q | 2 | 예산안 편성이란 무엇을 의미하나요?
# Fewshot Q | 2 | 예산 집행이란 무엇을 의미하나요?
# Context Number| 4|=====Answer=====
#  예산 사전의결의 원칙은 예산을 집행하기에 앞서 국회의 의결을 얻도록 하는 원칙입니다.
# =====REAL Answer=====
#  예산 사전의결의 원칙은 예산을 집행하기에 앞서 국회의 의결을 얻도록 하는 원칙입니다.
# =====149/124===============================================================================================================================================================================================================================================================
# Question:  예산이란 무엇을 의미하며 어떻게 표시되는가?
# Fewshot Q | 2 | 예산안 편성이란 무엇을 의미하나요?
# Fewshot Q | 2 | 예산 집행이란 무엇을 의미하나요?
# Fewshot Q | 2 | 예산순계란 무엇인가?
# Context Number| 4|=====Answer=====
#  예산이란 정부가 1년 동안 재정활동을 하는데 쓰이게 될 경비를 미리 계산하여 그 안을 마련하는 것을 의미하며, 다음의 절차를 거침: 예산안 심의, 예산 집행, 결산 및 회계검사.
# =====REAL Answer=====
#  예산이란 일정 기간 동안 국가의 재정활동에 얼마만큼 지출하고 이를 위해 재원을 어떻게 조달할 것인가를 금액으로 표시한 것이며, 회계연도 단위로 작성되어 운용 회계연도 독립의 원칙에 따라 특정 회계연도의 지출은 당해 회계연도의 수입으로 이루어진다.
# =====150/124===============================================================================================================================================================================================================================================================
# Question:  세입세출예산은 어떤 원칙에 따라 작성되는가?
# Fewshot Q | 2 | 세입예산은 어떻게 분류되는가?
# Fewshot Q | 2 | 일반회계의 세입은 어떠한 항목으로 구성되는가?
# Fewshot Q | 2 | 예산편성 시 어떤 원칙을 따라 편성 예비비 사용이 이루어지는가?
# Context Number| 4|=====Answer=====
#  세입세출예산은 총계주의 원칙에 따라 한 회계연도의 일체의 수입을 세입으로 하고 일체의 지출을 세출로 하여 작성하는 원칙을 따른다.
# =====REAL Answer=====
#  세입세출예산은 총계주의 원칙에 따라 한 회계연도의 일체의 수입을 세입으로 하고 일체의 지출을 세출로 하여 작성된다.
# =====159/124===============================================================================================================================================================================================================================================================
# Question:  국고채무부담행위는 어떤 경우에 국회의 의결을 받아야 하나요?
# Fewshot Q | 2 | 기금의 경우 특정 항목의 지출 금액을 얼마 이상 변경할 때 국회의 의결이 필요한가, 그리고 예산과 기금의 차이점은 무엇인가?
# Fewshot Q | 1 | 예산안 심의란 무엇을 하는 과정인가요?
# Fewshot Q | 2 | 국고채무부담행위는 어떤 상황에서 발생하는가?
# Context Number| 3|=====Answer=====
#  국고채무부담행위는 법률에 의하거나 세출예산 또는 계속비 총액범위 내의 것 외에 국가채무를 부담하는 행위를 할 때 미리 예산으로 국회의 의결을 받아야 합니다.
# =====REAL Answer=====
#  법률에 의하지 않거나 세출예산 또는 계속비 총액범위를 벗어나 국가채무를 부담할 때 국회의 의결을 받아야 합니다.
# =====161/124===============================================================================================================================================================================================================================================================
# Question:  본예산, 수정예산, 준예산의 차이점은 무엇인가요?
# Fewshot Q | 2 | 예산순계란 무엇인가?
# Fewshot Q | 2 | 예산과 기금의 차이점은 무엇인가?
# Fewshot Q | 2 | 기금의 경우 특정 항목의 지출 금액을 얼마 이상 변경할 때 국회의 의결이 필요한가, 그리고 예산과 기금의 차이점은 무엇인가?
# Context Number| 4|=====Answer=====
#  본예산은 국가의 재정계획을 정식으로 승인받은 것을 의미하고, 수정예산은 본예산에 대한 변경을 승인받은 것을 의미하며, 준예산은 본예산에 대한 변경을 승인받지 않은 것을 의미합니다.
# =====REAL Answer=====
#  본예산은 국회의 의결을 얻어 확정·성립된 통상적 의미의 예산이며, 수정예산은 정부가 예산을 국회에 제출한 후 국회의 심의·확정 전에 수정하여 제출하는 예산입니다. 준예산은 예산이 법정기한 내에 국회의 의결을 받지 못할 경우에 대비한 예산입니다.
# =====162/124===============================================================================================================================================================================================================================================================
# Question:  재정수지는 무엇을 판단하기 위한 재정 지표인가?
# Fewshot Q | 2 | 재정수지의 의미와 중요성은 무엇이며, 통합재정수지는 무엇인가?
# Fewshot Q | 2 | 통합재정수지는 무엇이며, 이를 통해 어떤 정보를 파악할 수 있나요?
# Fewshot Q | 2 | 관리재정수지는 어떻게 산출되며, 어떤 목적으로 사용되는가?
# Context Number| 4|=====Answer=====
#  재정수지는 국가재정의 건전성을 판단하기 위한 재정 지표로, 재정수입과 재정 지출의 차이를 의미합니다.
# =====REAL Answer=====
#  재정수지는 국가재정의 건전성을 판단하기 위한 재정 지표로, 재정수입과 재정 지출의 차이를 의미합니다.
# =====164/124===============================================================================================================================================================================================================================================================
# Question:  정부는 언제 재정규모를 축소하고 언제 확대하는가?
# Fewshot Q | 2 | 흑자재정과 적자재정의 의미는 무엇인가?
# Fewshot Q | 2 | 2024년에 예산이 증가하는 부처와 감소하는 부처의 차이는 무엇인가?
# Fewshot Q | 2 | 2024년에 일반회계의 총지출은 얼마이며, 중앙정부 총지출 대비 어느 정도의 비율을 차지하는가?
# Context Number| 4|=====Answer=====
#  정부는 경기 호황일 때 재정규모를 축소하고, 불황일 때 재정규모를 확대합니다.
# =====REAL Answer=====
#  정부는 경기조절을 위해 경기가 호황일 때는 경기의 과열을 막기 위하여 재정규모를 축소하고, 불황일 때에는 경기 회복을 위해 재정규모를 확대합니다.
# =====168/124===============================================================================================================================================================================================================================================================
# Question:  사회보장성기금은 정부가 어떤 목적을 위해 설치한 기금인가?
# Fewshot Q | 2 | 사회보장성기금수지를 산출하기 위해 어떤 기금들을 포함하며, 이 기금들은 정부에 의해 어떤 목적으로 설립되었는가?
# Fewshot Q | 2 | 사회보장성기금수지 산출 시 어떤 기금을 대상으로 하는가?
# Fewshot Q | 1 | 사회보장기여금의 정의와 그 목적에 대해 자세히 설명해주세요.
# Context Number| 4|=====Answer=====
#  사회보장성기금은 국민의 안정적 사회보장을 위해 사회보장 급여 지급을 목적으로 정부가 설치한 기금입니다.
# =====REAL Answer=====
#  국민의 안정적 사회보장을 위해 사회보장 급여 지급을 목적으로 한다.
# =====175/124===============================================================================================================================================================================================================================================================
# Question:  외국환평형기금채권은 왜 발행하는가?
# Fewshot Q | 2 | 국고채권은 어떤 목적으로 발행되는가?
# Fewshot Q | 2 | 출자금 상환지출은 어떠한 목적으로 이루어지는가?
# Fewshot Q | 2 | 국가채무는 어떤 차입 형태로 구분되는가?
# Context Number| 4|=====Answer=====
#  외국환평형기금채권은 외환 보유액 확충을 위해 발행된다.
# =====REAL Answer=====
#  외국환평형기금채권은 1998년 외환위기 이후 외환 보유액 확충을 위해 발행된다.
# =====178/124===============================================================================================================================================================================================================================================================
# Question:  국가채무(D1)는 어떤 지표로 활용되는가?
# Fewshot Q | 2 | 국가채무 통계에서 국가채무(D1)와 일반정부부채(D2)의 차이는 무엇인가?
# Fewshot Q | 2 | 국가채무(D1), 일반정부부채(D2), 공공부문부채(D3)의 각각의 정의와 이들 간의 차이점에 대해 설명해 주세요.
# Fewshot Q | 2 | 일반정부부채(D2)의 회계기준은 무엇에 따라 작성되는가?
# Context Number| 4|=====Answer=====
#  국가채무(D1)는 IMF의 정부재정통계편람(GFSM)에 기초하여 현금주의 기준으로 산출한 국가채무(중앙정부)에 지방자치단체(지방교육재정 포함)의 회계·기금까지 포함한 국가채무의 총액을 의미합니다.
# =====REAL Answer=====
#  국가채무(D1)는 중앙정부와 지방정부의 재정건전성 관리를 위한 지표로 활용된다.
# =====179/124===============================================================================================================================================================================================================================================================
# Question:  국가채무가 과다할 경우 어떤 위험이 발생할 수 있는가?
# Fewshot Q | 2 | 국가채무는 어떤 차입 형태로 구분되는가?
# Fewshot Q | 2 | 국가채무(중앙정부)의 정의와 포함되는 요소는 무엇인가요?
# Fewshot Q | 2 | 국가채무(중앙정부)란 무엇을 의미하나요?
# Context Number| 4|=====Answer=====
#  국가채무가 과다할 경우 재정의 위험 및 비용이 증가하여 재정의 건전성에 위협을 미칠 수 있습니다.
# =====REAL Answer=====
#  국가채무가 과다할 경우 재정의 위험 및 비용이 증가할 수 있다.
# =====183/124===============================================================================================================================================================================================================================================================
# Question:  우리나라는 언제부터 일반정부부채(D2)를 산출해 왔는가?
# Fewshot Q | 2 | 국가채무 통계에서 국가채무(D1)와 일반정부부채(D2)의 차이는 무엇인가?
# Fewshot Q | 2 | 일반정부부채(D2)의 포괄범위는 무엇인가?
# Fewshot Q | 2 | 국가채무(D1), 일반정부부채(D2), 공공부문부채(D3)의 각각의 정의와 이들 간의 차이점에 대해 설명해 주세요.
# Context Number| 4|=====Answer=====
#  우리나라는 2011년부터 일반정부부채(D2)를 산출해 왔습니다.
# =====REAL Answer=====
#  우리나라는 2011년부터 국가채무를 작성해 왔다.
# =====188/124===============================================================================================================================================================================================================================================================
# Question:  국가채무 통계에서 공공부문부채(D3)는 어떤 기준으로 산출되는가?
# Fewshot Q | 2 | 공공부문부채(D3)는 어떤 범위를 포괄하는 지표인가?
# Fewshot Q | 2 | 국가채무(D1), 일반정부부채(D2), 공공부문부채(D3)의 각각의 정의와 이들 간의 차이점에 대해 설명해 주세요.
# Fewshot Q | 2 | 국가채무 통계에서 국가채무(D1)와 일반정부부채(D2)의 차이는 무엇인가?
# Context Number| 4|=====Answer=====
#  공공부문부채(D3)는 PSDS에 기초하여 발생주의 기준으로 산출한 일반정부부채(D2)와 비금융공기업 단위를 포괄한 부채입니다.
# =====REAL Answer=====
#  공공부문부채(D3)는 PSDS에 기초하여 발생주의 기준으로 산출된 일반정부부채(D2)와 비금융공기업 단위를 포괄한 부채로 나타낸다.
# =====190/124===============================================================================================================================================================================================================================================================
# Question:  국가보증채무가 국가채무와 어떻게 관련되어 있나요?
# Fewshot Q | 2 | 국가채무는 어떤 차입 형태로 구분되는가?
# Fewshot Q | 2 | 국가보증채무란 무엇을 의미하나요?
# Fewshot Q | 2 | 국가채무(중앙정부)의 정의와 포함되는 요소는 무엇인가요?
# Context Number| 4|=====Answer=====
#  국가보증채무는 국가채무의 범위에 포함되지 않지만, 대신 지급해야 할 사유가 발생하는 경우 국가채무로 전환되기 때문에 국가채무를 관리하는 주요 보조 지표이며, 잠재적 부채 중 하나입니다.
# =====REAL Answer=====
#  국가보증채무는 국가채무의 범위에 포함되지 않지만, 대신 지급해야 할 사유가 발생하는 경우 국가채무로 전환되기 때문에 국가채무를 관리하는 주요 보조 지표이며, 잠재적 부채 중 하나임
# =====192/124===============================================================================================================================================================================================================================================================
# Question:  총수입은 무엇을 포함하는가?
# Fewshot Q | 2 | 일반회계의 세입은 어떠한 항목으로 구성되는가?
# Fewshot Q | 2 | 총지출이란 무엇을 의미하나요?
# Fewshot Q | 2 | 통합재정수입이란 무엇을 의미하는가?
# Context Number| 3|=====Answer=====
#  총수입은 일반회계, 특별회계, 기금 수입을 포함하며, 내부거래 등을 제외한 것이다.
# =====REAL Answer=====
#  국세, 세외수입, 기금수입 등을 통한 일반회계, 특별회계의 예산세입과 기금수입의 총합계에서 내부거래와 보전거래를 제외한 정부 수입을 포함한다.
# =====197/124===============================================================================================================================================================================================================================================================
# Question:  농어촌특별세와 주세는 어디에 사용되는가?
# Fewshot Q | 2 | 국세 중 목적세에는 어떤 세목이 포함되어 있으며, 각각은 구체적으로 어떤 자원에 대해 부과되는 세금인가요?
# Fewshot Q | 2 | 국세 중 목적세에는 어떤 세목이 포함되어 있으며, 교통·에너지·환경세는 어떤 자원에 대해 부과되는 세금인가요?
# Fewshot Q | 2 | 조세는 어떤 기준에 따라 분류할 수 있나요?
# Context Number| 4|=====Answer=====
#  농어촌특별세는 농어촌구조개선특별회계 재원으로 사용되고, 주세는 국가균형발전특별회계 재원으로 사용됩니다.
# =====REAL Answer=====
#  농어촌특별세와 주세는 각각 농어촌구조개선특별회계 및 국가균형발전특별회계 재원으로 사용된다.
# =====198/124===============================================================================================================================================================================================================================================================
# Question:  농어촌특별세와 주세의 소관기관은 무엇인가?
# Fewshot Q | 2 | 국세 중 목적세에는 어떤 세목이 포함되어 있으며, 각각은 구체적으로 어떤 자원에 대해 부과되는 세금인가요?
# Fewshot Q | 2 | 국세 중 목적세에는 어떤 세목이 포함되어 있으며, 교통·에너지·환경세는 어떤 자원에 대해 부과되는 세금인가요?
# Fewshot Q | 2 | 조세는 어떤 기준에 따라 분류할 수 있나요?
# Context Number| 4|=====Answer=====
#  농어촌특별세와 주세의 소관기관은 농림축산식품부와 기획재정부입니다.
# =====REAL Answer=====
#  농어촌특별세와 주세의 소관기관은 각각 농림축산식품부와 기획재정부이다.
# =====199/124===============================================================================================================================================================================================================================================================
# Question:  내국세에 포함되는 세목은 총 몇 개이며, 어떤 세목들이 포함되는가?
# Fewshot Q | 2 | 내국세에 포함되는 세목은 총 몇 개이며, 어떤 세목들이 포함되는가?
# Fewshot Q | 2 | 국세 중 목적세에는 어떤 세목이 포함되어 있으며, 교통·에너지·환경세는 어떤 자원에 대해 부과되는 세금인가요?
# Fewshot Q | 2 | 조세는 어떤 기준에 따라 분류할 수 있나요?
# Context Number| 4|=====Answer=====
#  내국세에는 8개 세목이 포함되며, 소득세, 법인세, 부가가치세, 상속세, 증여세, 개별소비세, 증권거래세, 인지세가 포함됩니다.
# =====REAL Answer=====
#  내국세에는 주세를 제외한 8개 세목이 포함되며, 소득세, 법인세, 부가가치세, 상속세, 증여세, 개별소비세, 증권거래세, 인지세가 포함된다.
# =====202/124===============================================================================================================================================================================================================================================================
# Question:  국세 중 목적세에는 어떤 세목이 포함되어 있나요?
# Fewshot Q | 2 | 국세 중 목적세에는 어떤 세목이 포함되어 있으며, 각각은 구체적으로 어떤 자원에 대해 부과되는 세금인가요?
# Fewshot Q | 2 | 국세 중 목적세에는 어떤 세목이 포함되어 있으며, 교통·에너지·환경세는 어떤 자원에 대해 부과되는 세금인가요?
# Fewshot Q | 2 | 국세수입은 무엇을 의미하나요?
# Context Number| 4|=====Answer=====
#  국세 중 목적세에는 교통·에너지·환경세, 교육세, 종합부동산세 등이 포함됩니다.
# =====REAL Answer=====
#  국세 중 목적세에는 교통·에너지·환경세, 교육세, 농어촌특별세가 포함되어 있습니다.
# =====204/124===============================================================================================================================================================================================================================================================
# Question:  세외수입은 어떤 종류의 수입으로 구성되어 있나요?
# Fewshot Q | 2 | 세외수입과 기금수입은 각각 어떤 종류의 수입으로 구성되어 있나요?
# Fewshot Q | 2 | 일반회계의 세입은 어떠한 항목으로 구성되는가?
# Fewshot Q | 2 | 세외수입은 어떠한 세부 항목으로 구성되어 있는가?
# Context Number| 3|=====Answer=====
#  세외수입은 행정서비스에 대한 공과금, 정부 재산에 대한 이용료, 벌금·과태료 성격의 수입 등으로 구성되며, 일반회계 세외수입은 사용료, 수수료, 교부금, 재산수입 등 경상적 수입과 분담금, 이월금, 전입금, 기부금 등 임시적 수입으로 구분되며, 특별회계 세외수입은 사업 수입과 사업외 수입으로 구분된다.
# =====REAL Answer=====
#  세외수입은 일반회계·특별회계 수입 중 조세 외의 수입으로, 행정서비스에 대한 공과금, 정부 재산에 대한 이용료, 벌금·과태료 성격의 수입 등으로 구성됩니다.
# =====207/124===============================================================================================================================================================================================================================================================
# Question:  기금수입의 주요 원천은 무엇인가?
# Fewshot Q | 1 | 기금수입은 무엇을 보유하고 운용하는 자금인가요?
# Fewshot Q | 2 | 세외수입과 기금수입은 각각 어떤 종류의 수입으로 구성되어 있나요?
# Fewshot Q | 2 | 사회보장성기금수지 산출 시 어떤 기금을 대상으로 하는가?
# Context Number| 4|=====Answer=====
#  기금수입의 주요 원천은 사회보장기여금, 경상이전수입, 재산수입입니다.
# =====REAL Answer=====
#  기금수입은 부담금, 정부출연금 등 다양한 재원으로 조성되고, 성질에 따라 사회 보장기여금, 경상이전수입, 재산수입 등으로 구분
# =====210/124===============================================================================================================================================================================================================================================================
# Question:  조세부담률은 어떻게 정의되며, 어떻게 계산되는가?
# Fewshot Q | 2 | 조세는 어떤 기준에 따라 분류할 수 있나요?
# Fewshot Q | 2 | 국민부담률은 어떻게 정의되는가?
# Fewshot Q | 2 | 국민부담률은 어떻게 계산되는가?
# Context Number| 4|=====Answer=====
#  조세부담률은 국내총생산(경상GDP)에서 조세수입이 차지하는 비중으로, 조세수입은 중앙정부가 부과하는 국세와 지방정부가 부과하는 지방세까지 포함합니다. 조세부담률은 조세수입/경상GDP = (국세수입+지방세수입)/경상GDP로 계산됩니다.
# =====REAL Answer=====
#  국내총생산(경상GDP)에서 조세수입이 차지하는 비중으로 국민들의 조세부담 정도를 측정하는 지표이며, 조세부담률 = 조세수입/경상GDP = (국세수입+지방세수입)/경상GDP로 계산된다.
# =====211/124===============================================================================================================================================================================================================================================================
# Question:  조세 부담률과 국민부담률은 무엇을 기준으로 구분되나요?
# Fewshot Q | 2 | 국민부담률은 어떻게 정의되는가?
# Fewshot Q | 2 | 국민부담률은 어떻게 계산되는가?
# Fewshot Q | 2 | 국민부담률의 정의와 계산 방법에 대해 자세히 설명해 주세요.
# Context Number| 3|=====Answer=====
#  조세부담률과 국민부담률을 구분하는 기준은 조세수입(국세와 지방세) 외에 사회보장기여금을 포함하는지 여부입니다.
# =====REAL Answer=====
#  조세 부담률과 국민부담률은 조세수입(국세와 지방세) 외에 사회보장기여금을 포함하는지 여부에 따라 구분됩니다.
# =====215/124===============================================================================================================================================================================================================================================================
# Question:  한국의 조세수입은 부과 목적에 따라 어떻게 구분되나요?
# Fewshot Q | 2 | 조세는 어떤 기준에 따라 분류할 수 있나요?
# Fewshot Q | 2 | 한국의 조세수입은 무엇을 의미하나요?
# Fewshot Q | 2 | 국세수입은 무엇을 의미하나요?
# Context Number| 4|=====Answer=====
#  한국의 조세수입은 부과 목적에 따라 국세와 지방세로 구분됩니다. 국세는 국가가 부과·징수하는 세금으로, 내국세, 관세, 교통·에너지·환경세, 교육세, 농어촌특별세, 종합부동산세 등 14개의 세목으로 구성됩니다. 지방세는 지방자치단체가 국가로부터 과세권을 부여받아 부과·징수하는 세금으로, 취득세, 등록면허세, 지방소비세, 레저세, 지역자원시설세, 지방교육세, 지방소득세, 주민세, 자동차세, 담배소득세, 재산세 등 11개의 세목으로 구성됩니다.
# =====REAL Answer=====
#  한국의 조세수입은 국가 또는 지방자치 단체의 일반적 지출을 충당하기위해 부과되는 보통세와 특정 지출 목적에 한정되어있는 목적세로 구분됩니다.
# =====219/124===============================================================================================================================================================================================================================================================
# Question:  기획재정부는 언제부터 중앙정부 재정지출 규모를 총지출 기준으로 산출하여 발표하기 시작했는가?
# Fewshot Q | 2 | 예산총계란 무엇을 말하나요?
# Fewshot Q | 2 | 총지출이란 무엇을 의미하나요?
# Fewshot Q | 2 | 통합재정이란 무엇을 의미하며, 어떤 목적을 가지고 있나요?
# Context Number| 4|=====Answer=====
#  기획재정부는 2004년 「2005~2009년 국가재정운용계획」에서 중앙정부 재정지출 규모를 총지출 기준으로 산출하여 발표하기 시작했습니다.
# =====REAL Answer=====
#  기획재정부는 2004년 「2005~2009년 국가재정운용계획」에 중앙정부 재정지출 규모를 총지출 기준으로 산출하여 발표하기 시작하였다.
# =====224/124===============================================================================================================================================================================================================================================================
# Question:  기금은 기능 및 주체에 따라 어떻게 구분되는가?
# Fewshot Q | 2 | 사회보장성기금수지 산출 시 어떤 기금을 대상으로 하는가?
# Fewshot Q | 2 | 일반회계, 특별회계, 기금 간의 차이점은 무엇인가요?
# Fewshot Q | 2 | 기금지출이란 무엇을 의미하며, 어떤 특징이 있나요?
# Context Number| 4|=====Answer=====
#  기금은 기능 및 주체에 따라 사회보험성기금, 계정성기금, 금융성기금, 사업성기금으로 구분됩니다.
# =====REAL Answer=====
#  기금은 사회보험성기금, 계정성기금, 금융성기금, 사업성기금으로 구분된다.
# =====231/124===============================================================================================================================================================================================================================================================
# Question:  예산의 목적외 사용 금지 원칙에 대한 예외가 허용되는 경우는 어떤 경우인가?
# Fewshot Q | 2 | 기금운용에 대한 법적 제약은 어떻게 되는가?
# Fewshot Q | 1 | 예산 프로그램과 성과관리 대상 프로그램은 원칙적으로 어떻게 일치해야 하며, 어떤 세부사업이 성과관리 대상에서 제외되는가?
# Fewshot Q | 2 | 예산편성 시 어떤 원칙을 따라 편성 예비비 사용이 이루어지는가?
# Context Number| 3|=====Answer=====
#  예산의 목적외 사용 금지 원칙에 대한 예외가 허용되는 경우는 다음이 있다. 1) 이용: 기관, 장(분야), 관(부문), 항(프로그램) 간에 예산을 상호 융통하는 경우, 2) 전용: 동일 항(프로그램) 내에서 세항(단위사업), 목 간에 예산을 상호 융통하는 경우, 3) 이체: 정부조직의 권한에 변동이 있는 경우 관련 예산의 소관을 변경하는 경우, 4) 조정: 세목 간에 예산을 상호 융통하거나, 동일 목에서 세세항(세부사업) 간에 부족한 예산을 융통하는 경우.
# =====REAL Answer=====
#  예산의 변경에 해당되는 이용, 전용, 조정, 이체는 예측하지 못했던 이유로 신축적인 예산운용이 필요할 경우에 대비하여 예산의 목적외 사용 금지 원칙에 대한 예외를 허용하는 경우임
# =====236/124===============================================================================================================================================================================================================================================================
# Question:  국가채무(D1)는 어떤 지표로 활용되며, 과다할 경우 어떤 위험이 발생하고, 관련된 대표적인 보고서는 무엇인가?
# Fewshot Q | 2 | 국가채무 통계에서 국가채무(D1)와 일반정부부채(D2)의 차이는 무엇인가?
# Fewshot Q | 2 | 국가채무(D1), 일반정부부채(D2), 공공부문부채(D3)의 각각의 정의와 이들 간의 차이점에 대해 설명해 주세요.
# Fewshot Q | 2 | 국가채무관리와 관련된 대표적인 보고서는 무엇인가?
# Context Number| 4|=====Answer=====
#  국가채무(D1)는 중앙정부와 지방자치단체의 채무를 현금주의 기준으로 산출한 지표로, 과다할 경우 재정의 위험 및 비용이 증가하여 적정 규모 수준에서 유지되도록 관리되어야 한다. 국가채무관리와 관련된 대표적인 보고서는 '국가 채무관리계획'과 '국가채무관리보고서'이다.
# =====REAL Answer=====
#  국가채무(D1)는 중앙정부와 지방정부의 재정건전성 관리를 위한 지표로 활용되며, 과다할 경우 재정의 위험 및 비용이 증가할 수 있다. 관련된 대표적인 보고서로는 '국가 채무관리계획'과 '국가채무관리보고서'가 있다.
# =====238/124===============================================================================================================================================================================================================================================================
# Question:  농어촌특별세와 주세는 어디에 사용되며, 각각의 소관기관은 무엇인가?
# Fewshot Q | 2 | 국세 중 목적세에는 어떤 세목이 포함되어 있으며, 각각은 구체적으로 어떤 자원에 대해 부과되는 세금인가요?
# Fewshot Q | 2 | 국세 중 목적세에는 어떤 세목이 포함되어 있으며, 교통·에너지·환경세는 어떤 자원에 대해 부과되는 세금인가요?
# Fewshot Q | 2 | 조세는 어떤 기준에 따라 분류할 수 있나요?
# Context Number| 4|=====Answer=====
#  농어촌특별세는 농어촌구조개선특별회계 재원으로 사용되고, 주세는 국가균형발전특별회계 재원으로 사용됩니다.
# =====REAL Answer=====
#  농어촌특별세는 농어촌구조개선특별회계에, 주세는 국가균형발전특별회계 재원으로 사용된다. 농어촌특별세의 소관기관은 농림축산식품부이며, 주세의 소관기관은 기획재정부이다.
# =====240/124===============================================================================================================================================================================================================================================================
# Question:  관세의 정의와 관세 행정사무를 담당하는 기관은 무엇인가?
# Fewshot Q | 1 | 관세는 어떤 조세이며, 어떤 기관이 관세 행정사무를 담당하는가?
# Fewshot Q | 2 | 조세는 어떤 기준에 따라 분류할 수 있나요?
# Fewshot Q | 2 | 국세 중 목적세에는 어떤 세목이 포함되어 있으며, 교통·에너지·환경세는 어떤 자원에 대해 부과되는 세금인가요?
# Context Number| 3|=====Answer=====
#  관세의 정의는 「관세법」에 의해서 수입되는 물건에 세금을 부과하는 조세이며, 주로 국경을 통과하는 시점에 원화 기준 수입가격에 비례하여 부과합니다. 관세 행정사무는 기획재정부 장관 소속의 관세청이 담당합니다.
# =====REAL Answer=====
#  관세는 수입되는 물건에 부과하는 조세이며, 관세 행정사무는 기획재정부 산하 조직인 관세청이 담당한다.
# =====245/124===============================================================================================================================================================================================================================================================
# Question:  이월이란 무엇을 의미하며, 이월명세서를 작성하여 제출해야 하는 기한은 언제인가?
# Fewshot Q | 2 | 이월명세서를 작성하여 제출해야 하는 기한은 언제인가?
# Fewshot Q | 2 | 이월이란 무엇을 의미하는가?
# Fewshot Q | 2 | 명시이월비란 무엇인가요?
# Context Number| 3|=====Answer=====
#  이월이란 세출예산 중 회계연도 내에 지출하지 못한 금액을 다음 회계연도의 세출 예산에 합산하여 반영하는 것을 의미하며, 이월명세서를 작성하여 제출해야 하는 기한은 12월 31일 기준으로 작성하여 1월 31일까지 기획재정부장관과 감사원에 제출해야 함
# =====REAL Answer=====
#  이월은 세출예산 중 회계연도 내에 지출하지 못한 금액을 다음 회계연도의 세출 예산에 합산하여 반영하는 것을 의미합니다. 이월명세서를 작성하여 제출해야 하는 기한은 12월 31일 기준으로 작성하여 1월 31일까지 기획재정부장관과 감사원에 제출해야 합니다.
# =====255/124===============================================================================================================================================================================================================================================================
# Question:  정부의 예비비는 주로 어떤 상황에서 사용되며, 그 사용의 법적 기준은 무엇인가요?
# Fewshot Q | 2 | 예산편성 시 어떤 원칙을 따라 편성 예비비 사용이 이루어지는가?
# Fewshot Q | 2 | 예비비 사용을 위해 국무회의 심의와 대통령 승인이 필요한 경우는 어떤 경우인가?
# Fewshot Q | 2 | 예비비는 무엇을 대비해 편성하는가?
# Context Number| 4|=====Answer=====
#  정부의 예비비는 예측할 수 없는 지출로 인한 예산의 부족에 대비해 두는 비용으로, 예산의 의결 이후에 예비비 사용이 필요한 경우 국무회의 심의와 대통령 승인을 거쳐 사용하고, 매 회계연도의 사용결과를 차기 국회에 제출하여 승인을 받아야 합니다.
# =====REAL Answer=====
#  정부의 예비비는 주로 예상치 못한 긴급 상황이나 자연재해, 경제 위기 등 예측 불가능한 상황에서 사용됩니다. 예비비의 사용은 국가재정법에 의해 엄격히 규제되며, 예비비 사용 시 대통령의 승인을 받아야 한다. 이는 예비비가 한정적이고 중요한 자원이기 때문에 효율적이고 적절한 사용이 이루어져야 하기 때문입니다.
# =====256/124===============================================================================================================================================================================================================================================================
# Question:  주택도시기금의 소관 기관은 무엇인가요?
# Fewshot Q | 2 | 주택지원 사업의 주요 시행주체는 누구인가?
# Fewshot Q | 2 | 민간임대(융자) 사업 중 공공지원민간임대 내역사업의 사업목적은 무엇인가요?
# Fewshot Q | 2 | 민간임대(융자) 사업 수혜자로 지정된 그룹은 무엇인가?
# Context Number| 4|=====Answer=====
#  주택도시기금의 소관 기관은 국토교통부입니다.
# =====REAL Answer=====
#  국토교통부
# =====257/124===============================================================================================================================================================================================================================================================
# Question:  전세임대 정책은 어떤 근거로 추진되고 있는가?
# Fewshot Q | 2 | 주택지원 사업의 주요 시행주체는 누구인가?
# Fewshot Q | 2 | 2024년 전세임대(융자) 주택지원 사업의 수혜자는 어떤 조건을 충족해야 하는가?
# Fewshot Q | 2 | 민간임대(융자) 사업 중 공공지원민간임대 내역사업의 사업목적은 무엇인가요?
# Context Number| 3|=====Answer=====
#  주택도시기금법 제9조와 공공주택 특별법 제3조의2 및 제45조의2가 근거가 되고 있습니다.
# =====REAL Answer=====
#  주택도시기금법 제9조, 공공주택 특별법 제3조의2 및 제45조의2
# =====258/124===============================================================================================================================================================================================================================================================
# Question:  '17년 11월에 발표된 사회통합형 주거사다리 구축을 위한 주거복지로드맵에는 어떤 내용이 포함되어 있나요?
# Fewshot Q | 2 | 2024년 전세임대(융자) 주택지원 사업의 수혜자는 어떤 조건을 충족해야 하는가?
# Fewshot Q | 2 | 주택지원 사업의 주요 시행주체는 누구인가?
# Fewshot Q | 2 | 민간임대(융자) 사업 중 공공지원민간임대 내역사업의 사업목적은 무엇인가요?
# Context Number| 3|=====Answer=====
#  사회통합형 주거사다리 구축을 위한 주거복지로드맵은 주거복지의 다양한 형태로 17만호를 공급하는 것을 목표로, 노인일자리 및 사회활동지원, 노인맞춤 돌봄서비스, 경로당 냉·난방비 및 양곡비 지원 등 다양한 주거복지 서비스를 제공하는 것을 포함하고 있습니다.
# =====REAL Answer=====
#  2017년 11월에 발표된 사회통합형 주거사다리 구축을 위한 주거복지로드맵에는 2018~2022년간 임차형 17만호 공급에 관한 내용이 포함되어 있습니다.
# ...
# Context Number| 4|=====Answer=====
#  새만금개발청의 '인건비' 비중은 0.1%이며, 프로그램목표 Ⅰ-1의 예산은 10,689백원입니다.
# =====REAL Answer=====
#  인건비의 비중은 38.4%이며, 새만금개발청의 프로그램목표 Ⅰ-1의 예산은 10,689억원입니다.
# =====418/124===============================================================================================================================================================================================================================================================
# Question:  해양경찰청의 '성과지표 수'와 '해양경찰역량강화' 프로그램의 예산은 각각 몇 개이며, 얼마인가요?
# Fewshot Q | 2 | 해양경찰청의 2024년도 성과지표는 몇 개인가요?
# Fewshot Q | 2 | 재외동포청, 병무청, 국세청, 관세청, 통계청의 '24년 예산안은 각각 얼마인가?
# Fewshot Q | 2 | 국세청의 성과관리대상 사업의 재정현황에서 세입확보를 위해 설정된 프로그램 목표와 관련 성과지표는 무엇인가요?
# Context Number| 4|=====Answer=====
#  해양경찰청의 성과지표 수는 5개이며, '해양경찰역량강화' 프로그램의 예산은 75,798백만원입니다.
# =====REAL Answer=====
#  해양경찰청의 성과지표 수는 5개이며, 해양경찰역량강화 프로그램의 예산은 64,450백만원입니다.
# =====423/124===============================================================================================================================================================================================================================================================
# Question:  국가재정법 시행 이후 성과계획서 및 성과보고서, 재정사업 평가 등의 성과관리 주요내용이 규정되었는데, 이러한 성과관리의 주요 내용은 무엇인가?
# Fewshot Q | 2 | 국가재정법 시행 이후 성과계획서 및 성과보고서, 재정사업 평가 등의 성과관리 주요내용과 성과계획서 및 성과보고서 작성에 대한 규정은 무엇인가?
# Fewshot Q | 2 | 기획재정부는 매년 어떤 작업을 수행하여 중앙관서의 성과관리를 강화하고 있는가? 부처들은 성과계획서 작성을 어떻게 수행해야 하며, 성과목표를 수립할 때 고려해야 하는 요소는 무엇인가?
# Fewshot Q | 2 | 국가재정법 시행으로 성과관리제도가 법제화된 연도는 언제인가요?
# Context Number| 4|=====Answer=====
#  ① 성과계획서: 중앙관서 및 기금관리주체의 전략목표 및 성과목표를 달성하기 위한 연도별 시행계획 ② 성과보고서: 재정사업의 성과평가 결과 ③ 재정사업 평가: 재정사업의 계획 수립, 집행 과정 및 결과 등에 대한 점검ㆍ분석ㆍ평가
# =====REAL Answer=====
#  ① 성과목표관리: 재정사업에 대한 성과목표, 성과지표 등의 설정 및 그 달성을 위한 집행과정ㆍ결과의 관리 ② 성과평가: 재정사업의 계획 수립, 집행과정 및 결과 등에 대한 점검ㆍ분석ㆍ평가
# =====424/124===============================================================================================================================================================================================================================================================
# Question:  성과계획서 및 성과보고서의 작성에 대한 규정은 무엇인가?
# Fewshot Q | 2 | 국가재정법 시행 이후 성과계획서 및 성과보고서, 재정사업 평가 등의 성과관리 주요내용과 성과계획서 및 성과보고서 작성에 대한 규정은 무엇인가?
# Fewshot Q | 2 | 성과목표관리를 위한 성과계획서 및 성과보고서 작성 시 어떤 사항이 포함되어야 하는가?
# Fewshot Q | 2 | 성과계획서는 어떤 목적으로 작성되며, 작성 시 어떤 요소들이 사전에 설정되고 관리되는가, 그리고 그 공개는 어떤 효과를 가져오는가?
# Context Number| 3|=====Answer=====
#  성과계획서와 성과보고서는 매년 예산요구서와 기금운용계획안을 제출할 때 함께 제출되어야 하며, 각 중앙관서의 장과 기금관리주체는 성과계획서와 전년도의 성과보고서를 첨부하여야 한다.
# =====REAL Answer=====
#  각 중앙관서의 장 및 기금관리주체는 재정사업 성과목표관리를 위하여 매년 예산 및 기금에 관한 성과목표ㆍ성과지표가 포함된 성과계획서 및 성과보고서를 작성하여야 한다.
# =====428/124===============================================================================================================================================================================================================================================================
# Question:  국가재정법에 따라 성과계획서를 작성해야 하는 대상기관은 누구인가요?
# Fewshot Q | 2 | 국가재정법 시행 이후 성과계획서 및 성과보고서, 재정사업 평가 등의 성과관리 주요내용과 성과계획서 및 성과보고서 작성에 대한 규정은 무엇인가?
# Fewshot Q | 2 | 국가재정법에 따라 성과계획서를 작성해야 하는 대상기관은 누구인가요?
# Fewshot Q | 2 | 기획재정부는 매년 어떤 작업을 수행하여 중앙관서의 성과관리를 강화하고 있는가? 부처들은 성과계획서 작성을 어떻게 수행해야 하며, 성과목표를 수립할 때 고려해야 하는 요소는 무엇인가?
# Context Number| 4|=====Answer=====
#  국가재정법에 따라 성과계획서를 작성해야 하는 대상기관은 각 중앙관서의 장과 기금관리주체입니다.
# =====REAL Answer=====
#  국가재정법에 따라 성과계획서를 작성해야 하는 대상기관은 국가재정법(제4장의2)에 따라 예산요구서를 제출하는 모든 중앙관서의 장과 기금관리주체입니다.
# =====429/124===============================================================================================================================================================================================================================================================
# Question:  기획재정부는 매년 어떤 작업을 수행하여 중앙관서의 성과관리를 강화하고 있는가?
# Fewshot Q | 2 | 기획재정부는 매년 어떤 작업을 수행하여 중앙관서의 성과관리를 강화하고 있는가? 부처들은 성과계획서 작성을 어떻게 수행해야 하며, 성과목표를 수립할 때 고려해야 하는 요소는 무엇인가?
# Fewshot Q | 2 | 국가재정법 시행 이후 성과계획서 및 성과보고서, 재정사업 평가 등의 성과관리 주요내용과 성과계획서 및 성과보고서 작성에 대한 규정은 무엇인가?
# Fewshot Q | 2 | 성과계획서의 공개는 어떤 효과를 가져오는가?
# Context Number| 4|=====Answer=====
#  기획재정부는 매년 중앙관서의 체계적 성과관리를 위하여 성과계획서 작성지침을 각 부처에 통보하여 각 부처의 성과계획서 작성 방법과 기준을 제시하고 있다.
# =====REAL Answer=====
#  매년 성과계획서 작성지침을 각 부처에 통보하여 각 부처의 성과계획서 작성 방법과 기준을 제시하고 있다.
# =====437/124===============================================================================================================================================================================================================================================================
# Question:  예산 프로그램과 성과관리 대상프로그램은 원칙적으로 어떻게 설정해야 하는가?
# Fewshot Q | 1 | 예산 프로그램과 성과관리 대상 프로그램은 원칙적으로 어떻게 일치해야 하며, 어떤 세부사업이 성과관리 대상에서 제외되는가?
# Fewshot Q | 2 | 예산편성 시 어떤 원칙을 따라 편성 예비비 사용이 이루어지는가?
# Fewshot Q | 2 | 예산과 기금의 차이점은 무엇인가?
# Context Number| 3|=====Answer=====
#  예산 프로그램과 성과관리 대상 프로그램은 원칙적으로 일치해야 하며, 인건비, 기본행정경비 등 성과관리 실익이 작은 일부 사업을 제외하는 경우, 해당 세부사업만 제외하여 성과계획서를 작성해야 한다.
# =====REAL Answer=====
#  원칙적으로 예산 체계상 모든 사업을 성과계획 목표체계에 포함하여 설정하되, 인건비, 기본행정경비 등 성과관리 실익이 작은 일부사업을 제외해야 한다.
# =====438/124===============================================================================================================================================================================================================================================================
# Question:  어떤 세부사업이 성과관리 대상에서 제외되는가?
# Fewshot Q | 1 | 예산 프로그램과 성과관리 대상 프로그램은 원칙적으로 어떻게 일치해야 하며, 어떤 세부사업이 성과관리 대상에서 제외되는가?
# Fewshot Q | 2 | 조세지출 기본계획의 목적과 원칙은 무엇이며, 조세지출 성과관리체계에는 어떤 구분이 있으며 각각 어떤 내용을 다루는가?
# Fewshot Q | 2 | 성과목표를 수립할 때 고려해야 하는 요소는 무엇인가?
# Context Number| 3|=====Answer=====
#  성과관리 대상에서 제외되는 세부사업으로는 인건비, 기본행정경비, 정부내부거래, 보전지출, 교부금, 차입이자 상환, 예비비, 청사관리, 타부처 수행사업, 위원회·자문회의 운영, 출연금 사업 등이 있습니다.
# =====REAL Answer=====
#  인건비, 기본경비, 정부내부거래, 보전지출, 교부금, 차입이자 상환, 예비비, 청사관리, 타부처 수행사업, 위원회·자문회의 운영, 출연금 사업 등이 성과관리 대상에서 제외된다.
# =====439/124===============================================================================================================================================================================================================================================================
# Question:  국가연구개발사업 중 어떤 경우 성과관리 대상에서 제외되는가?
# Fewshot Q | 1 | 예산 프로그램과 성과관리 대상 프로그램은 원칙적으로 어떻게 일치해야 하며, 어떤 세부사업이 성과관리 대상에서 제외되는가?
# Fewshot Q | 2 | 관리재정수지와 통합재정수지의 차이점은 무엇인가?
# Fewshot Q | 2 | 조세지출 기본계획의 목적과 원칙은 무엇이며, 조세지출 성과관리체계에는 어떤 구분이 있으며 각각 어떤 내용을 다루는가?
# Context Number| 3|=====Answer=====
#  국가연구개발사업 중 정부연구소 인건비, 출연(연) 운영지원 비목만으로 구성된 사업은 성과관리 대상에서 제외된다.
# =====REAL Answer=====
#  정부연구소 인건비, 출연(연) 운영지원 비목만으로 구성된 사업이 성과관리 대상에서 제외된다.
# =====444/124===============================================================================================================================================================================================================================================================
# Question:  정부입법 관리를 강화하고 법제지원을 확대하기 위해 어떤 프로그램이 운영되고 있는가?
# Fewshot Q | 2 | 기금운용에 대한 법적 제약은 어떻게 되는가?
# Fewshot Q | 2 | 정부는 어떤 방식으로 스타트업의 글로벌화를 촉진하고 있으며, 국내 스타트업의 글로벌화를 위해 어떤 프로그램이 강화되고 있는가?
# Fewshot Q | 2 | 재정융자제도의 현재 운영 방식과 정부가 수행하는 재정융자사업의 예시는 무엇인가요?
# Context Number| 4|=====Answer=====
#  정부입법 관리를 강화하고 법제지원을 확대하기 위해, 정부는 법제정보서비스, 정부입법 총괄관리, 법제업무정보화지원, 법제전문성향상 등 다양한 프로그램을 운영하고 있습니다.
# =====REAL Answer=====
#  정부입법 관리를 강화하고 법제지원을 확대하기 위해 '정부입법 관리를 강화하고 법제지원을 확대함으로써 국민이 체감하는 국정성과 창출에 기여한다'는 프로그램이 운영되고 있다.
# =====445/124===============================================================================================================================================================================================================================================================
# Question:  '24년 예산안에서 전략목표 Ⅰ. 고위공직자 범죄를 근절하여 공직사회의 투명성과 신뢰성을 제고한다.'의 예산은 얼마인가요?
# Fewshot Q | 2 | 국민권익증진을 위해 반부패·청렴 정책을 강화하고, 현장중심의 행정을 펼치는 프로그램목표의 '24년 예산안은 얼마인가요?
# Fewshot Q | 2 | 국세청의 '24년 예산안은 얼마인가?
# Fewshot Q | 2 | 예산과정의 전반적인 의미와 그 중요성은 무엇인가?
# Context Number| 3|=====Answer=====
#  7,454백만원
# =====REAL Answer=====
#  24년 예산안에서 전략목표 Ⅰ. 고위공직자 범죄를 근절하여 공직사회의 투명성과 신뢰성을 제고한다.'의 예산은 7,454억원입니다.
# =====448/124===============================================================================================================================================================================================================================================================
# Question:  국방산업 육성을 위한 방위사업의 성과지표 중 '전략무기체계 핵심·원천기술 개발 및 방위산업 육성을 지원한다'의 성과지표는 무엇인가?
# Fewshot Q | 2 | 국방력 건설을 위한 방위사업의 재정현황과 성과지표는 어떻게 되는가?
# Fewshot Q | 2 | 한국의 국방 강화를 위해 어떤 무기체계 전력화 강화에 중점을 두고 투자하고 있는가?
# Fewshot Q | 2 | 국방사업의 성과지표 중 '유도무기체계를 적기 전력화한다'의 성과지표는 어떤 내용을 담고 있는가?
# Context Number| 3|=====Answer=====
#  전략무기체계 핵심·원천기술 개발 및 방위산업 육성을 지원한다는 성과지표는 '핵심기술 적용률'으로, 35.5%의 목표치를 가지고 있습니다.
# =====REAL Answer=====
#  전략무기체계 핵심·원천기술 개발 및 방위산업 육성을 지원한다는 성과지표는 '핵심기술 적용률'로, 목표치는 35.5%이다.
# =====450/124===============================================================================================================================================================================================================================================================
# Question:  조세지출이란 무엇을 의미하는가?
# Fewshot Q | 2 | 조세는 어떤 기준에 따라 분류할 수 있나요?
# Fewshot Q | 2 | 한국의 조세수입은 무엇을 의미하나요?
# Fewshot Q | 2 | 국세수입은 무엇을 의미하나요?
# Context Number| 4|=====Answer=====
#  조세지출은 일반적인 조세체계에서 벗어난 조세특례에 의하여 납세자에 대한 재정지원을 목적으로 발생하는 국가 세입의 감소를 의미합니다.
# =====REAL Answer=====
#  조세지출이란 '일반적인 조세체계에서 벗어난 조세특례에 의하여 납세자에 대한 재정지원을 목적으로 발생하는 국가 세입의 감소'를 의미한다.
# =====452/124===============================================================================================================================================================================================================================================================
# Question:  중앙-지방 간 재정조정제도에서 어떤 재원을 이전하여 수직적 재정 불균형을 해소하는가?
# Fewshot Q | 2 | 지방재정조정제도의 목적은 무엇인가?
# Fewshot Q | 2 | 지방교부세는 어떤 목적을 위해 자치단체에 교부되는 재원인가?
# Fewshot Q | 2 | 지방교부세와 국고보조금의 차이는 무엇인가요?
# Context Number| 3|=====Answer=====
#  중앙-지방 간 재정조정제도에서 재원을 이전하여 수직적 재정 불균형을 해소하는 것은 지방교부세와 국고보조금이다.
# =====REAL Answer=====
#  중앙-지방 간 재정조정제도에서는 지방교부세, 국고보조금, 조정교부금 등의 재원을 이전하여 수직적 재정 불균형을 해소한다.
# =====454/124===============================================================================================================================================================================================================================================================
# Question:  2022년 지방자치단체의 세입예산은 어떻게 구성되어 있으며, 이전수입이 어떤 비율을 차지하는가?
# Fewshot Q | 2 | 2024년도 예산안에서 세외수입 중 가장 큰 규모를 차지하는 세입항목은 무엇인가?
# Fewshot Q | 2 | 2022년 기준, 일반회계와 기타특별회계의 이월금 차지 비율은 얼마인가?
# Fewshot Q | 2 | 2024년 국세수입은 얼마이며, 일반회계와 특별회계의 규모는 각각 얼마인가요?
# Context Number| 4|=====Answer=====
#  2022년 지방자치단체의 세입예산은 일반회계 202.8조원, 특별회계 84.5조원, 기금 21.3조원으로 총 308.6조원으로 구성되어 있으며, 이전수입은 85.9조원으로 세입예산의 27.9%를 차지했습니다.
# =====REAL Answer=====
#  2022년 지방자치단체의 세입예산은 자체수입이 46.1%, 이전수입이 45.7%를 차지하며, 중앙정부의 이전 재원으로 구성된 이전수입은 자체수입 비율과 비슷한 수준을 보인다.
# =====457/124===============================================================================================================================================================================================================================================================
# Question:  조세지출예산서의 제출 시기, 목적, 법적 근거 및 도입 배경은 무엇인가?
# Fewshot Q | 2 | 조세지출예산서는 무엇을 분석하고 집계하는 자료이며, 조세지출은 어떤 법과 유형에 따라 어떻게 구분되는가?
# Fewshot Q | 2 | 조세지출이란 무엇이며, 조세지출 예산서는 무엇을 포함하고 있는가?
# Fewshot Q | 2 | 조세는 어떤 기준에 따라 분류할 수 있나요?
# Context Number| 3|=====Answer=====
#  조세지출예산서의 제출 시기는 국회에 다음연도 예산안을 제출할 때이며, 목적은 재원배분의 효율성 및 재정운영의 투명성을 제고하기 위함이다. 법적 근거는 「조세특례제한법」 제142조의2(조세지출예산서의 작성), 「국가재정법」 제9조(재정정보의 공표) 및 제34조(예산안의 첨부서류)이다. 도입 배경은 조세지출의 관리와 통제를 위한 수단으로서의 조세지출 예산서를 작성하여 국회에 제출하기 위함이다.
# =====REAL Answer=====
#  조세지출예산서는 정부가 국회에 다음 연도 예산안을 제출할 때 부수서류로 제출되며, 재원배분의 효율성 및 재정운영의 투명성을 제고하기 위한 목적으로 제출된다. 법적 근거는 「조세특례제한법」 제142조의2, 「국가재정법」 제9조 및 제34조에 근거하며, 1996년 OECD 가입을 계기로 도입되어 정부 재정의 투명성을 제고하고 국가 재원을 보다 효율적으로 운용하기 위해 도입된 제도이다.
# =====462/124===============================================================================================================================================================================================================================================================
# Question:  재정융자사업은 무엇을 의미하며, 어떤 장점을 가지고 있는가?
# Fewshot Q | 2 | 정부가 수행하는 다양한 재정융자사업에는 어떤 것들이 있나요?
# Fewshot Q | 2 | 재정융자사업은 어떤 역할을 하는가?
# Fewshot Q | 2 | 재정융자제도의 현재 운영 방식과 정부가 수행하는 재정융자사업의 예시는 무엇인가요?
# Context Number| 4|=====Answer=====
#  재정융자사업은 정부가 자금을 민간의 사적 경제주체에 대해 대출해 주고 회수하는 활동을 말하며, 시장금리보다 낮은 이자율로 지원되어 자금 부족 현상을 완화해 주며, 취약계층 지원, 기후재난 등에 대응하기 위해 정부가 수행할 수 있는 강력하고 실 효성 있는 정책수단입니다.
# =====REAL Answer=====
#  재정융자사업은 정부가 자금을 민간의 사적 경제주체에 대해 대출해 주고 회수하는 활동을 말하며, 민간 금융의 역할이 미약하거나 부족한 부분에 직접 자금을 공급할 수 있는 장점이 있습니다.
# =====470/124===============================================================================================================================================================================================================================================================
# Question:  2023년 예산안 기준 가장 큰 융자지출 규모는 어느 분야이며, 비중은 얼마인가?
# Fewshot Q | 1 | 2023년에 융자 규모가 두 번째로 큰 분야는 무엇이며, 어떤 규모를 가지고 있으며, 전체 융자 규모 중 차지하는 비중은 얼마인가?
# Fewshot Q | 2 | 2023년 예산안을 기준으로 주택도시기금의 재정융자사업이 전체 융자사업의 어느 정도를 차지하나요?
# Fewshot Q | 2 | 2023년 예산안을 기준으로 재정융자 규모는 얼마이며, 총지출 대비 어느 정도를 차지하나요?
# Context Number| 3|=====Answer=====
#  2023년 예산안 기준 사회복지 분야가 융자지출 규모가 가장 큰 분야로 26조 8,963억원이며, 전체 융자 규모 중 64.3%를 차지합니다.
# =====REAL Answer=====
#  사회복지 분야로 26조 8,963억원이며, 비중은 64.3%이다.
# =====479/124===============================================================================================================================================================================================================================================================
# Question:  슬로바키아의 재정 투명성 개선을 위해 IMF가 어떤 권고를 하고 있나요?
# Fewshot Q | 2 | 통합재정 통계를 작성하는 기준은 무엇이며, 어떤 변화가 있었나요?
# Fewshot Q | 2 | 재정융자 정보의 투명성을 강화하기 위해 어떠한 개선이 이루어지고 있는가?
# Fewshot Q | 2 | 통합재정지출이란 무엇을 의미하며, 통합재정 통계를 작성하는 기준과 중요성은 무엇인가요?
# Context Number| 3|=====Answer=====
#  IMF는 슬로바키아의 재정 투명성 개선을 위해 세금 지출에 대한 전략적 검토와 외부 감사의 강화, 다년간 지출 상한제 도입, 중기 예산 계획을 위한 제도 개선 등을 권고하고 있습니다.
# =====REAL Answer=====
#  IMF는 세금 지출에 대한 전략적 검토와 외부 감사의 강화, 다년간 지출 상한제 도입, 중기예산계획을 위한 제도 개선 등을 권고하고 있습니다.
# =====486/124===============================================================================================================================================================================================================================================================
# Question:  지난 10년간(2010~2021년)의 세외수입은 GDP 대비 어떻게 변화하였으며, 이에 대한 어떤 분석이 제시되었는가?
# Fewshot Q | 2 | 보통교부세의 법정률은 어떻게 변화해왔는가?
# Fewshot Q | 2 | 세외수입은 어떠한 세부 항목으로 구성되어 있는가?
# Fewshot Q | 2 | 조세지출예산서는 무엇을 분석하고 집계하는 자료이며, 조세지출은 어떤 법과 유형에 따라 어떻게 구분되는가?
# Context Number| 3|=====Answer=====
#  지난 10년간(2010~2021년)의 세외수입은 GDP 대비 1.4%p 감소하였다.
# =====REAL Answer=====
#  지난 10년간(2010~2021년)의 세외수입은 GDP 대비 1.4%포인트 감소하였으며, 세입 증가와 비교하여 정부의 수입이 소폭 증가한 것으로 분석되었다.
# =====487/124===============================================================================================================================================================================================================================================================
# Question:  IMF는 슬로바키아의 재정 투명성을 어떻게 평가하고 있나요?
# Fewshot Q | 2 | 통합재정지출이란 무엇을 의미하며, 통합재정 통계를 작성하는 기준과 중요성은 무엇인가요?
# Fewshot Q | 2 | 통합재정수입이란 무엇을 의미하는가?
# Fewshot Q | 2 | 정부는 어떤 방식으로 국민에게 국가재정 현황을 투명하게 공개하고 있는가?
# Context Number| 3|=====Answer=====
#  IMF는 슬로바키아의 재정 투명성을 우수 사례로 평가하고, 재정 공개, 예산 편성 및 위험 관리 측면에서 대부분 IMF의 재정 투명성 규약(Fiscal Transparency Code)에 부합한다고 평가했습니다.
# =====REAL Answer=====
#  IMF는 슬로바키아가 재정 공개, 예산 편성 및 위험 관리 측면에서 대부분 IMF의 재정 투명성 규약(Fiscal Transparency Code)의 우수 사례에 부합한다고 평가하고 있습니다.
# =====491/124===============================================================================================================================================================================================================================================================
# Question:  자치단체 보조금과 민간보조금은 각각 어떤 비율로 증가했는가?
# Fewshot Q | 2 | 지방교부세는 어떤 목적을 위해 자치단체에 교부되는 재원인가?
# Fewshot Q | 2 | 지방교부세와 국고보조금의 차이는 무엇인가요?
# Fewshot Q | 2 | 세외수입과 기금수입은 각각 어떤 종류의 수입으로 구성되어 있나요?
# Context Number| 4|=====Answer=====
#  자치단체 보조금은 52.3%로 감소했으며, 민간보조금은 18.4% 증가했습니다.
# =====REAL Answer=====
#  자치단체 보조금은 2019년 대비 2022년에 35% 증가하였고, 민간보조금은 10.9% 증가하였다.
# {'average_precision': 0.6992922283090569, 'average_recall': 0.7361225126528861, 'average_f1_score': 0.6704858018226832}

# %% [markdown]
# py pdf 0.663
#
# ptmu 0.6740735793987513
#
# PDFPlumberLoader 0.6516317411146649 0.655995454987313(0.4), 0.6578699067809993(0.2), 0.6578699067809993(0.1)
#
# PDFPlumberLoader NEW:  0.6508706361694363, 0.6545265117992998 (0.4)
#
# NEWNEW : 0.6690379419494678(0.5)recursive,chunk1000,overlap200
#
# konlp : 0.639172573877312 chunk 400
#
# 0.6502491672498713 chunk 2000

# %%
from save_module import save


weight = [0.5,0.5]
train_faiss_db, train_bm_retrievier = make_db(train_df) 
test_faiss_db, test_bm_retrievier = make_db(test_df)
fewshot_faiss_db, fewshot_bm_retrievier = fewshot_db(train_df)

train_k = 1
train_bm_retrievier.k = train_k
#knn_retriever.k = train_k
faiss_retriever = train_faiss_db.as_retriever(search_type="mmr",search_kwargs={'k':train_k} )
train_ensemble_retriever = EnsembleRetriever(
    retrievers=[train_bm_retrievier, faiss_retriever], weights=weight
)

test_k = 2
test_bm_retrievier.k = test_k
#test_knn_retriever.k = test_k
test_faiss_retriever = test_faiss_db.as_retriever(search_type="mmr",search_kwargs={'k':test_k} )
test_ensemble_retriever = EnsembleRetriever(
    retrievers=[test_bm_retrievier, test_faiss_retriever], weights=weight
)

fewshot_k = 3
fewshot_bm_retrievier.k = fewshot_k
#fewshot_knn_retriever.k = fewshot_k
fewshot_faiss_retriever = fewshot_faiss_db.as_retriever(search_type="mmr",search_kwargs={'k':fewshot_k} )
fewshot_ensemble_retriever = EnsembleRetriever(
    retrievers=[fewshot_bm_retrievier, fewshot_faiss_retriever], weights=weight
)

results = run(train_ensemble_retriever, test_ensemble_retriever, fewshot_faiss_retriever, test_df, llm, verbose=True)
save(results)
